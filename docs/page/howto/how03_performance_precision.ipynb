# %% [raw]
# ---
# title: "How to Load an Audio-to-Score Alignment Corpus and Compare Performances"
# description: "PerformancePrecisionLoader, MetricMap, granularity-tagged MatchClaims, tempo comparison"
# ---

# %% [markdown]
# # How to Load an Audio-to-Score Alignment Corpus and Compare Performances
#
# A *Performance Precision* specimen bundles one symbolic score with several
# recorded performances of it, plus the audio-to-score alignments that connect
# them. This guide loads such a specimen in a single call and arrives at the
# question the corpus was built to answer: **how do different pianists shape the
# same piece in time?**
#
# The specimen here is Chopin's Nocturne in E♭ major, Op. 9 No. 2 — a `.solo`
# score, a Verovio timemap giving each measure's position in quarter notes, and
# an `Alignments/` directory holding three alignment files (note, bar, beat) for
# each of seven recordings. By the end we will read, for one shared score
# position, the seven different moments at which each pianist played it.
#
# The arc:
#
# 1. Load the whole specimen in one call.
# 2. Inspect the measure structure recovered from the timemap.
# 3. Read the score {{< glossary Timeline >}} (in quarters) and see how a
#    `measure+offset` label resolves.
# 4. Read the per-performer {{< glossary Timeline >}}s (in seconds).
# 5. Inspect the {{< glossary MatchClaim >}}s, tagged by granularity.
# 6. Compare the performers' timing through the {{< glossary AlignmentBundle >}}.

# %% [markdown]
# ## Setup

# %%
from __future__ import annotations

from collections import Counter
from fractions import Fraction

import pandas as pd

from timetoalign.core import EnharmonicPitch
from timetoalign.loader.alignment import PerformancePrecisionLoader
from timetoalign.loader.tabular.solo import SoloLoader
from timetoalign.testdata import ensure_data

SPECIMEN_DIR = ensure_data("performance_precision")
SOLO_FILE = SPECIMEN_DIR / "Chopin Nocturne Op. 9 No. 2.solo"
# Out:
# /home/laser/miniconda3/envs/timetoalign/lib/python3.11/site-packages/partitura/__init__.py:9: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## 1. Load the specimen in one call
#
# {{< glossary PerformancePrecisionLoader >}} ingests the whole directory — the
# `.solo` score, the Verovio timemap, and every per-performer alignment file —
# through the standard two-phase loader pattern. `from_file()` is the one-line
# form.

# %%
loader = PerformancePrecisionLoader.from_file(SPECIMEN_DIR)
loader
# Out:
# PerformancePrecisionLoader(performers=7, claims=6769)

# %% [markdown]
# Seven recordings, and a few thousand {{< glossary MatchClaim >}}s linking the
# score to them. Everything below reads from this single loaded object.

# %% [markdown]
# ***
#
# ## 2. The measure structure
#
# The Verovio timemap records each measure's absolute position in quarter notes.
# The loader walks it into a {{< glossary MetricMap >}} — a
# {{< glossary ConversionMap >}} from a quarter position to its measure count —
# and exposes it directly:

# %%
metric_map = loader.metric_map
metric_map
# Out:
# MetricMap(n_measures=38, total_length=425/2)

# %% [markdown]
# Thirty-eight measures spanning 212.5 quarters. The companion `.meter` file is
# deliberately left unread: it encodes only meter *changes* (four rows across
# the whole piece), so it cannot by itself bound the final measure. The
# timemap's terminal position supplies that bound, which is why it is preferred
# here.
#
# The paired {{< glossary MetricalPositionMap >}} is a
# {{< glossary CombinationMap >}} carrying both directions of the
# measure↔quarter relationship. `quarters_at(mc, beat)` goes from a metrical
# position to a quarter coordinate; `mn_at(quarters)` returns the measure-number
# label at a quarter position:

# %%
metrical_position_map = loader.metrical_position_map

{
    "downbeat of MC 2 (quarters)": metrical_position_map.quarters_at(2),
    "downbeat of MC 3 (quarters)": metrical_position_map.quarters_at(3),
    "measure label at quarter 0.0": metrical_position_map.mn_at(0.0),
    "measure label at quarter 7.0": metrical_position_map.mn_at(7.0),
}
# Out:
# {'downbeat of MC 2 (quarters)': Fraction(1, 2),
#  'downbeat of MC 3 (quarters)': Fraction(13, 2),
#  'measure label at quarter 0.0': '1',
#  'measure label at quarter 7.0': '3'}

# %% [markdown]
# ***
#
# ## 3. The score timeline
#
# The score is a logical {{< glossary Timeline >}} measured in quarters. It holds
# every note of the `.solo` score, each placed at its absolute quarter position.
# Its stored UID is `score:clt1`.

# %%
score_tl = loader.create_timeline(uid="score:clt1")
score_tl
# Out:
# ContinuousLogicalTimeline(id='score:clt1', length=425/2, unit=quarters, events=2494, children=0, cmaps=1)

# %% [markdown]
# ### How a `measure+offset` label becomes a quarter coordinate
#
# Both the `.solo` score and the alignment files write score positions as
# `"<measure>+<offset>"`, where the offset is given in **whole notes**. The
# resolver is one line of arithmetic — `measure_start + offset × 4` (the `× 4`
# converts whole notes to quarters) — with one wrinkle: **measure 0 is the
# anacrusis** (the pickup), whose offsets are measured back from a virtual
# full-bar downbeat preceding the first sounding note. The very first note of
# the piece, labelled `0+11/8`, therefore lands exactly on quarter 0:

# %%
first_three = score_tl.get_events().table.slice(0, 3).to_pandas()
first_three[["id", "start"]]
# Out:
#         id                                             start
# 0  score:0  {'value': 0.0, 'numerator': 0, 'denominator': 1}
# 1  score:1  {'value': 0.5, 'numerator': 1, 'denominator': 2}
# 2  score:2  {'value': 0.5, 'numerator': 1, 'denominator': 2}

# %% [markdown]
# A {{< glossary TimeStamp >}} is the primary way to query the score timeline at
# a coordinate — here the downbeat of the first full measure, half a quarter in:

# %%
score_tl.get_timestamp(Fraction(1, 2))
# Out:
# TimeStamp(axis=0.5, source='score:clt1' (interpolated))

# %% [markdown]
# ### A note on pitch
#
# The score timeline carries pitch as the raw MIDI pitch integer that the
# `.solo` file recorded — faithful to the source, which notes no accidental
# spelling. When a *typed* pitch field is wanted, it lives on a freshly composed
# `SoloLoader` reading the same `.solo` file. There the field materialises as
# `EnharmonicPitch` scalars, and the canonical glyphs ♯/♭ render in their
# labels:

# %%
solo = SoloLoader.from_file(SOLO_FILE)
pitch_field = solo.events.get_field(EnharmonicPitch)
{"first five pitches": [pitch_field[i] for i in range(5)]}
# Out:
# {'first five pitches': [EP(A♯/B♭4),
#   EP(A♯/B♭4),
#   EP(D♯/E♭2),
#   EP(G5),
#   EP(D♯/E♭2)]}

# %% [markdown]
# Because `.solo` records only the MIDI pitch number, an enharmonic pair such as
# `G♯3` and `A♭3` both surface as the same number — the field reports what was
# represented, not what could be inferred.

# %% [markdown]
# ***
#
# ## 4. The performance timelines
#
# Each recording is a physical {{< glossary Timeline >}} measured in seconds, one
# event per aligned note onset. Their stored UIDs follow
# `perf:<performer>:cpt1`, so the Ashkenazy recording is
# `perf:Chopin_Ashkenazy:cpt1`:

# %%
performer_keys = [tl.name for tl in loader.create_timelines() if tl is not score_tl]
performer_keys
# Out:
# ['Chopin_Ashkenazy',
#  'Chopin_Barenboim',
#  'Chopin_Freire',
#  'Chopin_Horowitz',
#  'Chopin_Pollini',
#  'Chopin_Rachmaninoff',
#  'Chopin_Rubinstein']

# %%
ashkenazy = loader.create_timeline(uid="perf:Chopin_Ashkenazy:cpt1")
ashkenazy
# Out:
# ContinuousPhysicalTimeline(id='perf:Chopin_Ashkenazy:cpt1', length=209.142, unit=seconds, events=480, children=0)

# %% [markdown]
# A score position is in quarters; a performance position is in seconds. The
# alignment is what relates the two, and that is carried by the
# {{< glossary MatchClaim >}}s.

# %% [markdown]
# ***
#
# ## 5. The granularity-tagged MatchClaims
#
# The {{< glossary AlignmentBundle >}} assembles the loaded data: the score in
# its own group, each performance standalone, and every alignment row as a
# cross-group {{< glossary MatchClaim >}}.

# %%
bundle = loader.create_bundle()
bundle
# Out:
# AlignmentBundle(id='bundle:AlignmentBundle_1', name='Chopin Nocturne Op. 9 No. 2', timelines=8, groups=1)

# %% [markdown]
# Each recording was aligned at three granularities — note, bar, and beat — and
# the loader records which one produced each claim in its provenance metadata:
# the aligning agent's `identifier` carries the granularity. Counting the
# claims for one performer shows the shape of a single recording's alignment.
# A {{< glossary NOMATCH >}} claim prints its unmatched score coordinate
# (`score:clt1@…`) so the dangling position stays legible at a glance:

# %%
bundle.cross_group_claims
# Out:
# [MatchClaim(instant: score:clt1@0.0 <-> perf:Chopin_Ashkenazy:cpt1@9.5),
#  MatchClaim(instant: score:clt1@0.5 <-> perf:Chopin_Ashkenazy:cpt1@10.3),
#  MatchClaim(instant: score:clt1@1.0 <-> perf:Chopin_Ashkenazy:cpt1@11.1),
#  MatchClaim(instant: score:clt1@1.5 <-> perf:Chopin_Ashkenazy:cpt1@11.6),
#  MatchClaim(instant: score:clt1@2.0 <-> perf:Chopin_Ashkenazy:cpt1@12.0),
#  MatchClaim(instant: score:clt1@2.5 <-> perf:Chopin_Ashkenazy:cpt1@12.4),
#  MatchClaim(instant: score:clt1@3.0 <-> perf:Chopin_Ashkenazy:cpt1@12.9),
#  MatchClaim(instant: score:clt1@3.5 <-> perf:Chopin_Ashkenazy:cpt1@13.4),
#  MatchClaim(instant: score:clt1@4.0 <-> perf:Chopin_Ashkenazy:cpt1@13.9),
#  MatchClaim(instant: score:clt1@4.5 <-> perf:Chopin_Ashkenazy:cpt1@14.4),
#  MatchClaim(instant: score:clt1@5.0 <-> perf:Chopin_Ashkenazy:cpt1@14.8),
#  MatchClaim(instant: score:clt1@5.5 <-> perf:Chopin_Ashkenazy:cpt1@15.2),
#  MatchClaim(instant: score:clt1@6.0 <-> perf:Chopin_Ashkenazy:cpt1@15.6),
#  MatchClaim(instant: score:clt1@6.5 <-> perf:Chopin_Ashkenazy:cpt1@16.2),
#  MatchClaim(instant: score:clt1@7.0 <-> perf:Chopin_Ashkenazy:cpt1@16.6),
#  MatchClaim(instant: score:clt1@7.5 <-> perf:Chopin_Ashkenazy:cpt1@17.0),
#  MatchClaim(instant: score:clt1@8.0 <-> perf:Chopin_Ashkenazy:cpt1@17.7),
#  MatchClaim(instant: score:clt1@8.5 <-> perf:Chopin_Ashkenazy:cpt1@18.1),
#  MatchClaim(instant: score:clt1@9.0 <-> perf:Chopin_Ashkenazy:cpt1@18.6),
#  MatchClaim(instant: score:clt1@9.5 <-> perf:Chopin_Ashkenazy:cpt1@19.1),
#  MatchClaim(instant: score:clt1@10.0 <-> perf:Chopin_Ashkenazy:cpt1@19.5),
#  MatchClaim(instant: score:clt1@10.5 <-> perf:Chopin_Ashkenazy:cpt1@19.9),
#  MatchClaim(instant: score:clt1@11.0 <-> perf:Chopin_Ashkenazy:cpt1@20.3),
#  MatchClaim(instant: score:clt1@11.5 <-> perf:Chopin_Ashkenazy:cpt1@20.6),
#  MatchClaim(instant: score:clt1@12.0 <-> perf:Chopin_Ashkenazy:cpt1@21.0),
#  MatchClaim(instant: score:clt1@12.5 <-> perf:Chopin_Ashkenazy:cpt1@21.5),
#  MatchClaim(instant: score:clt1@13.0 <-> perf:Chopin_Ashkenazy:cpt1@21.8),
#  MatchClaim(instant: score:clt1@13.5 <-> perf:Chopin_Ashkenazy:cpt1@22.2),
#  MatchClaim(instant: score:clt1@14.0 <-> perf:Chopin_Ashkenazy:cpt1@22.7),
#  MatchClaim(instant: score:clt1@14.5 <-> perf:Chopin_Ashkenazy:cpt1@23.0),
#  MatchClaim(instant: score:clt1@15.0 <-> perf:Chopin_Ashkenazy:cpt1@23.4),
#  MatchClaim(instant: score:clt1@15.5 <-> perf:Chopin_Ashkenazy:cpt1@23.8),
#  MatchClaim(instant: score:clt1@16.0 <-> perf:Chopin_Ashkenazy:cpt1@24.2),
#  MatchClaim(instant: score:clt1@16.5 <-> perf:Chopin_Ashkenazy:cpt1@24.6),
#  MatchClaim(instant: score:clt1@17.0 <-> perf:Chopin_Ashkenazy:cpt1@25.0),
#  MatchClaim(instant: score:clt1@17.5 <-> perf:Chopin_Ashkenazy:cpt1@25.4),
#  MatchClaim(instant: score:clt1@18.0 <-> perf:Chopin_Ashkenazy:cpt1@25.7),
#  MatchClaim(instant: score:clt1@18.5 <-> perf:Chopin_Ashkenazy:cpt1@26.3),
#  MatchClaim(instant: score:clt1@19.0 <-> perf:Chopin_Ashkenazy:cpt1@26.9),
#  MatchClaim(instant: score:clt1@19.5 <-> perf:Chopin_Ashkenazy:cpt1@27.4),
#  MatchClaim(instant: score:clt1@20.0 <-> perf:Chopin_Ashkenazy:cpt1@27.9),
#  MatchClaim(instant: score:clt1@20.2 <-> perf:Chopin_Ashkenazy:cpt1@28.2),
#  MatchClaim(instant: score:clt1@20.5 <-> perf:Chopin_Ashkenazy:cpt1@28.4),
#  MatchClaim(instant: score:clt1@20.8 <-> perf:Chopin_Ashkenazy:cpt1@28.6),
#  MatchClaim(instant: score:clt1@21.0 <-> perf:Chopin_Ashkenazy:cpt1@28.9),
#  MatchClaim(instant: score:clt1@21.2 <-> perf:Chopin_Ashkenazy:cpt1@29.2),
#  MatchClaim(instant: score:clt1@21.5 <-> perf:Chopin_Ashkenazy:cpt1@29.6),
#  MatchClaim(instant: score:clt1@22.0 <-> perf:Chopin_Ashkenazy:cpt1@30.0),
#  MatchClaim(instant: score:clt1@22.5 <-> perf:Chopin_Ashkenazy:cpt1@30.4),
#  MatchClaim(instant: score:clt1@23.0 <-> perf:Chopin_Ashkenazy:cpt1@30.9),
#  MatchClaim(instant: score:clt1@23.5 <-> perf:Chopin_Ashkenazy:cpt1@31.3),
#  MatchClaim(instant: score:clt1@24.0 <-> perf:Chopin_Ashkenazy:cpt1@31.9),
#  MatchClaim(instant: score:clt1@24.5 <-> perf:Chopin_Ashkenazy:cpt1@32.7),
#  MatchClaim(instant: score:clt1@25.0 <-> perf:Chopin_Ashkenazy:cpt1@33.3),
#  MatchClaim(instant: score:clt1@25.5 <-> perf:Chopin_Ashkenazy:cpt1@33.7),
#  MatchClaim(instant: score:clt1@26.0 <-> perf:Chopin_Ashkenazy:cpt1@34.3),
#  MatchClaim(instant: score:clt1@26.2 <-> perf:Chopin_Ashkenazy:cpt1@34.6),
#  MatchClaim(instant: score:clt1@26.5 <-> perf:Chopin_Ashkenazy:cpt1@34.9),
#  MatchClaim(instant: score:clt1@26.8 <-> perf:Chopin_Ashkenazy:cpt1@35.2),
#  MatchClaim(instant: score:clt1@27.0 <-> perf:Chopin_Ashkenazy:cpt1@35.4),
#  MatchClaim(instant: score:clt1@27.2 <-> perf:Chopin_Ashkenazy:cpt1@35.7),
#  MatchClaim(instant: score:clt1@27.5 <-> perf:Chopin_Ashkenazy:cpt1@36.0),
#  MatchClaim(instant: score:clt1@28.0 <-> perf:Chopin_Ashkenazy:cpt1@36.6),
#  MatchClaim(instant: score:clt1@28.5 <-> perf:Chopin_Ashkenazy:cpt1@37.1),
#  MatchClaim(instant: score:clt1@29.0 <-> perf:Chopin_Ashkenazy:cpt1@37.5),
#  MatchClaim(instant: score:clt1@29.2 <-> perf:Chopin_Ashkenazy:cpt1@37.6),
#  MatchClaim(instant: score:clt1@29.5 <-> perf:Chopin_Ashkenazy:cpt1@37.8),
#  MatchClaim(instant: score:clt1@29.8 <-> perf:Chopin_Ashkenazy:cpt1@38.1),
#  MatchClaim(instant: score:clt1@30.0 <-> perf:Chopin_Ashkenazy:cpt1@38.3),
#  MatchClaim(instant: score:clt1@30.2 <-> perf:Chopin_Ashkenazy:cpt1@38.6),
#  MatchClaim(instant: score:clt1@30.5 <-> perf:Chopin_Ashkenazy:cpt1@38.8),
#  MatchClaim(instant: score:clt1@30.8 <-> perf:Chopin_Ashkenazy:cpt1@39.1),
#  MatchClaim(instant: score:clt1@31.0 <-> perf:Chopin_Ashkenazy:cpt1@39.3),
#  MatchClaim(instant: score:clt1@31.2 <-> perf:Chopin_Ashkenazy:cpt1@39.5),
#  MatchClaim(instant: score:clt1@31.5 <-> perf:Chopin_Ashkenazy:cpt1@39.7),
#  MatchClaim(instant: score:clt1@31.8 <-> perf:Chopin_Ashkenazy:cpt1@39.9),
#  MatchClaim(instant: score:clt1@32.0 <-> perf:Chopin_Ashkenazy:cpt1@40.1),
#  MatchClaim(instant: score:clt1@32.2 <-> perf:Chopin_Ashkenazy:cpt1@40.3),
#  MatchClaim(instant: score:clt1@32.5 <-> perf:Chopin_Ashkenazy:cpt1@40.5),
#  MatchClaim(instant: score:clt1@32.8 <-> perf:Chopin_Ashkenazy:cpt1@40.7),
#  MatchClaim(instant: score:clt1@33.0 <-> perf:Chopin_Ashkenazy:cpt1@41.0),
#  MatchClaim(instant: score:clt1@33.2 <-> perf:Chopin_Ashkenazy:cpt1@41.3),
#  MatchClaim(instant: score:clt1@33.5 <-> perf:Chopin_Ashkenazy:cpt1@41.7),
#  MatchClaim(instant: score:clt1@34.0 <-> perf:Chopin_Ashkenazy:cpt1@42.2),
#  MatchClaim(instant: score:clt1@34.5 <-> perf:Chopin_Ashkenazy:cpt1@42.6),
#  MatchClaim(instant: score:clt1@35.0 <-> perf:Chopin_Ashkenazy:cpt1@43.1),
#  MatchClaim(instant: score:clt1@35.5 <-> perf:Chopin_Ashkenazy:cpt1@43.5),
#  MatchClaim(instant: score:clt1@36.0 <-> perf:Chopin_Ashkenazy:cpt1@43.9),
#  MatchClaim(instant: score:clt1@36.5 <-> perf:Chopin_Ashkenazy:cpt1@44.3),
#  MatchClaim(instant: score:clt1@37.0 <-> perf:Chopin_Ashkenazy:cpt1@44.7),
#  MatchClaim(instant: score:clt1@37.5 <-> perf:Chopin_Ashkenazy:cpt1@45.1),
#  MatchClaim(instant: score:clt1@38.0 <-> perf:Chopin_Ashkenazy:cpt1@45.6),
#  MatchClaim(instant: score:clt1@38.5 <-> perf:Chopin_Ashkenazy:cpt1@46.1),
#  MatchClaim(instant: score:clt1@39.0 <-> perf:Chopin_Ashkenazy:cpt1@46.6),
#  MatchClaim(instant: score:clt1@39.5 <-> perf:Chopin_Ashkenazy:cpt1@47.0),
#  MatchClaim(instant: score:clt1@40.0 <-> perf:Chopin_Ashkenazy:cpt1@47.4),
#  MatchClaim(instant: score:clt1@40.5 <-> perf:Chopin_Ashkenazy:cpt1@47.8),
#  MatchClaim(instant: score:clt1@41.0 <-> perf:Chopin_Ashkenazy:cpt1@48.2),
#  MatchClaim(instant: score:clt1@41.5 <-> perf:Chopin_Ashkenazy:cpt1@48.6),
#  MatchClaim(instant: score:clt1@42.0 <-> perf:Chopin_Ashkenazy:cpt1@49.0),
#  MatchClaim(instant: score:clt1@42.5 <-> perf:Chopin_Ashkenazy:cpt1@49.6),
#  MatchClaim(instant: score:clt1@43.0 <-> perf:Chopin_Ashkenazy:cpt1@50.3),
#  MatchClaim(instant: score:clt1@43.5 <-> perf:Chopin_Ashkenazy:cpt1@50.7),
#  MatchClaim(instant: score:clt1@44.0 <-> perf:Chopin_Ashkenazy:cpt1@51.3),
#  MatchClaim(instant: score:clt1@44.2 <-> perf:Chopin_Ashkenazy:cpt1@51.6),
#  MatchClaim(instant: score:clt1@44.5 <-> perf:Chopin_Ashkenazy:cpt1@51.9),
#  MatchClaim(instant: score:clt1@44.8 <-> perf:Chopin_Ashkenazy:cpt1@52.1),
#  MatchClaim(instant: score:clt1@45.0 <-> perf:Chopin_Ashkenazy:cpt1@52.6),
#  MatchClaim(instant: score:clt1@45.2 <-> perf:Chopin_Ashkenazy:cpt1@53.1),
#  MatchClaim(instant: score:clt1@45.5 <-> perf:Chopin_Ashkenazy:cpt1@53.4),
#  MatchClaim(instant: score:clt1@46.0 <-> perf:Chopin_Ashkenazy:cpt1@54.0),
#  MatchClaim(instant: score:clt1@46.5 <-> perf:Chopin_Ashkenazy:cpt1@54.5),
#  MatchClaim(instant: score:clt1@47.0 <-> perf:Chopin_Ashkenazy:cpt1@54.9),
#  MatchClaim(instant: score:clt1@47.5 <-> perf:Chopin_Ashkenazy:cpt1@55.3),
#  MatchClaim(instant: score:clt1@48.0 <-> perf:Chopin_Ashkenazy:cpt1@55.9),
#  MatchClaim(instant: score:clt1@48.5 <-> perf:Chopin_Ashkenazy:cpt1@56.6),
#  MatchClaim(instant: score:clt1@49.0 <-> perf:Chopin_Ashkenazy:cpt1@57.1),
#  MatchClaim(instant: score:clt1@49.5 <-> perf:Chopin_Ashkenazy:cpt1@57.5),
#  MatchClaim(instant: score:clt1@50.0 <-> perf:Chopin_Ashkenazy:cpt1@58.0),
#  MatchClaim(instant: score:clt1@50.5 <-> perf:Chopin_Ashkenazy:cpt1@58.5),
#  MatchClaim(instant: score:clt1@51.0 <-> perf:Chopin_Ashkenazy:cpt1@59.0),
#  MatchClaim(instant: score:clt1@51.5 <-> perf:Chopin_Ashkenazy:cpt1@59.8),
#  MatchClaim(instant: score:clt1@52.0 <-> perf:Chopin_Ashkenazy:cpt1@60.4),
#  MatchClaim(instant: score:clt1@52.5 <-> perf:Chopin_Ashkenazy:cpt1@60.9),
#  MatchClaim(instant: score:clt1@53.0 <-> perf:Chopin_Ashkenazy:cpt1@61.3),
#  MatchClaim(instant: score:clt1@53.5 <-> perf:Chopin_Ashkenazy:cpt1@61.7),
#  MatchClaim(instant: score:clt1@54.0 <-> perf:Chopin_Ashkenazy:cpt1@62.1),
#  MatchClaim(instant: score:clt1@54.5 <-> perf:Chopin_Ashkenazy:cpt1@62.8),
#  MatchClaim(instant: score:clt1@55.0 <-> perf:Chopin_Ashkenazy:cpt1@63.3),
#  MatchClaim(instant: score:clt1@55.5 <-> perf:Chopin_Ashkenazy:cpt1@63.8),
#  MatchClaim(instant: score:clt1@56.0 <-> perf:Chopin_Ashkenazy:cpt1@64.3),
#  MatchClaim(instant: score:clt1@56.5 <-> perf:Chopin_Ashkenazy:cpt1@64.9),
#  MatchClaim(instant: score:clt1@56.8 <-> perf:Chopin_Ashkenazy:cpt1@65.1),
#  MatchClaim(instant: score:clt1@57.0 <-> perf:Chopin_Ashkenazy:cpt1@65.6),
#  MatchClaim(instant: score:clt1@57.4 <-> perf:Chopin_Ashkenazy:cpt1@66.3),
#  MatchClaim(instant: score:clt1@57.5 <-> perf:Chopin_Ashkenazy:cpt1@66.6),
#  MatchClaim(instant: score:clt1@58.0 <-> perf:Chopin_Ashkenazy:cpt1@67.2),
#  MatchClaim(instant: score:clt1@58.5 <-> perf:Chopin_Ashkenazy:cpt1@67.6),
#  MatchClaim(instant: score:clt1@59.0 <-> perf:Chopin_Ashkenazy:cpt1@68.0),
#  MatchClaim(instant: score:clt1@59.5 <-> perf:Chopin_Ashkenazy:cpt1@68.4),
#  MatchClaim(instant: score:clt1@60.0 <-> perf:Chopin_Ashkenazy:cpt1@68.8),
#  MatchClaim(instant: score:clt1@60.5 <-> perf:Chopin_Ashkenazy:cpt1@69.4),
#  MatchClaim(instant: score:clt1@61.0 <-> perf:Chopin_Ashkenazy:cpt1@69.8),
#  MatchClaim(instant: score:clt1@61.5 <-> perf:Chopin_Ashkenazy:cpt1@70.2),
#  MatchClaim(instant: score:clt1@62.0 <-> perf:Chopin_Ashkenazy:cpt1@70.6),
#  MatchClaim(instant: score:clt1@62.5 <-> perf:Chopin_Ashkenazy:cpt1@70.9),
#  MatchClaim(instant: score:clt1@63.0 <-> perf:Chopin_Ashkenazy:cpt1@71.3),
#  MatchClaim(instant: score:clt1@63.5 <-> perf:Chopin_Ashkenazy:cpt1@71.8),
#  MatchClaim(instant: score:clt1@64.0 <-> perf:Chopin_Ashkenazy:cpt1@72.2),
#  MatchClaim(instant: score:clt1@64.5 <-> perf:Chopin_Ashkenazy:cpt1@72.6),
#  MatchClaim(instant: score:clt1@65.0 <-> perf:Chopin_Ashkenazy:cpt1@73.0),
#  MatchClaim(instant: score:clt1@65.5 <-> perf:Chopin_Ashkenazy:cpt1@73.3),
#  MatchClaim(instant: score:clt1@66.0 <-> perf:Chopin_Ashkenazy:cpt1@73.7),
#  MatchClaim(instant: score:clt1@66.5 <-> perf:Chopin_Ashkenazy:cpt1@74.2),
#  MatchClaim(instant: score:clt1@67.0 <-> perf:Chopin_Ashkenazy:cpt1@74.5),
#  MatchClaim(instant: score:clt1@67.5 <-> perf:Chopin_Ashkenazy:cpt1@74.9),
#  MatchClaim(instant: score:clt1@68.0 <-> perf:Chopin_Ashkenazy:cpt1@75.4),
#  MatchClaim(instant: score:clt1@68.5 <-> perf:Chopin_Ashkenazy:cpt1@75.8),
#  MatchClaim(instant: score:clt1@69.0 <-> perf:Chopin_Ashkenazy:cpt1@76.2),
#  MatchClaim(instant: score:clt1@69.5 <-> perf:Chopin_Ashkenazy:cpt1@76.7),
#  MatchClaim(instant: score:clt1@70.0 <-> perf:Chopin_Ashkenazy:cpt1@77.4),
#  MatchClaim(instant: score:clt1@70.5 <-> perf:Chopin_Ashkenazy:cpt1@78.0),
#  MatchClaim(instant: score:clt1@71.0 <-> perf:Chopin_Ashkenazy:cpt1@78.5),
#  MatchClaim(instant: score:clt1@71.5 <-> perf:Chopin_Ashkenazy:cpt1@79.1),
#  MatchClaim(instant: score:clt1@72.0 <-> perf:Chopin_Ashkenazy:cpt1@79.8),
#  MatchClaim(instant: score:clt1@72.5 <-> perf:Chopin_Ashkenazy:cpt1@80.6),
#  MatchClaim(instant: score:clt1@73.0 <-> perf:Chopin_Ashkenazy:cpt1@81.7),
#  MatchClaim(instant: score:clt1@73.5 <-> perf:Chopin_Ashkenazy:cpt1@82.4),
#  MatchClaim(instant: score:clt1@73.8 <-> perf:Chopin_Ashkenazy:cpt1@82.7),
#  MatchClaim(instant: score:clt1@74.0 <-> perf:Chopin_Ashkenazy:cpt1@83.0),
#  MatchClaim(instant: score:clt1@74.2 <-> perf:Chopin_Ashkenazy:cpt1@83.2),
#  MatchClaim(instant: score:clt1@74.5 <-> perf:Chopin_Ashkenazy:cpt1@83.4),
#  MatchClaim(instant: score:clt1@74.8 <-> perf:Chopin_Ashkenazy:cpt1@83.7),
#  MatchClaim(instant: score:clt1@75.0 <-> perf:Chopin_Ashkenazy:cpt1@84.1),
#  MatchClaim(instant: score:clt1@75.4 <-> perf:Chopin_Ashkenazy:cpt1@84.5),
#  MatchClaim(instant: score:clt1@75.5 <-> perf:Chopin_Ashkenazy:cpt1@84.7),
#  MatchClaim(instant: score:clt1@76.0 <-> perf:Chopin_Ashkenazy:cpt1@85.2),
#  MatchClaim(instant: score:clt1@76.5 <-> perf:Chopin_Ashkenazy:cpt1@85.7),
#  MatchClaim(instant: score:clt1@77.0 <-> perf:Chopin_Ashkenazy:cpt1@86.2),
#  MatchClaim(instant: score:clt1@77.2 <-> perf:Chopin_Ashkenazy:cpt1@86.4),
#  MatchClaim(instant: score:clt1@77.5 <-> perf:Chopin_Ashkenazy:cpt1@86.7),
#  MatchClaim(instant: score:clt1@77.8 <-> perf:Chopin_Ashkenazy:cpt1@86.9),
#  MatchClaim(instant: score:clt1@78.0 <-> perf:Chopin_Ashkenazy:cpt1@87.1),
#  MatchClaim(instant: score:clt1@78.2 <-> perf:Chopin_Ashkenazy:cpt1@87.3),
#  MatchClaim(instant: score:clt1@78.5 <-> perf:Chopin_Ashkenazy:cpt1@87.6),
#  MatchClaim(instant: score:clt1@78.8 <-> perf:Chopin_Ashkenazy:cpt1@87.8),
#  MatchClaim(instant: score:clt1@79.0 <-> perf:Chopin_Ashkenazy:cpt1@88.0),
#  MatchClaim(instant: score:clt1@79.2 <-> perf:Chopin_Ashkenazy:cpt1@88.2),
#  MatchClaim(instant: score:clt1@79.5 <-> perf:Chopin_Ashkenazy:cpt1@88.4),
#  MatchClaim(instant: score:clt1@79.8 <-> perf:Chopin_Ashkenazy:cpt1@88.6),
#  MatchClaim(instant: score:clt1@80.0 <-> perf:Chopin_Ashkenazy:cpt1@88.8),
#  MatchClaim(instant: score:clt1@80.2 <-> perf:Chopin_Ashkenazy:cpt1@89.0),
#  MatchClaim(instant: score:clt1@80.5 <-> perf:Chopin_Ashkenazy:cpt1@89.2),
#  MatchClaim(instant: score:clt1@80.8 <-> perf:Chopin_Ashkenazy:cpt1@89.4),
#  MatchClaim(instant: score:clt1@81.0 <-> perf:Chopin_Ashkenazy:cpt1@89.7),
#  MatchClaim(instant: score:clt1@81.2 <-> perf:Chopin_Ashkenazy:cpt1@90.0),
#  MatchClaim(instant: score:clt1@81.5 <-> perf:Chopin_Ashkenazy:cpt1@90.4),
#  MatchClaim(instant: score:clt1@82.0 <-> perf:Chopin_Ashkenazy:cpt1@91.0),
#  MatchClaim(instant: score:clt1@82.5 <-> perf:Chopin_Ashkenazy:cpt1@91.5),
#  MatchClaim(instant: score:clt1@83.0 <-> perf:Chopin_Ashkenazy:cpt1@91.9),
#  MatchClaim(instant: score:clt1@83.5 <-> perf:Chopin_Ashkenazy:cpt1@92.3),
#  MatchClaim(instant: score:clt1@84.0 <-> perf:Chopin_Ashkenazy:cpt1@92.8),
#  MatchClaim(instant: score:clt1@84.5 <-> perf:Chopin_Ashkenazy:cpt1@93.2),
#  MatchClaim(instant: score:clt1@85.0 <-> perf:Chopin_Ashkenazy:cpt1@93.6),
#  MatchClaim(instant: score:clt1@85.5 <-> perf:Chopin_Ashkenazy:cpt1@94.0),
#  MatchClaim(instant: score:clt1@86.0 <-> perf:Chopin_Ashkenazy:cpt1@94.6),
#  MatchClaim(instant: score:clt1@86.5 <-> perf:Chopin_Ashkenazy:cpt1@95.1),
#  MatchClaim(instant: score:clt1@87.0 <-> perf:Chopin_Ashkenazy:cpt1@95.6),
#  MatchClaim(instant: score:clt1@87.5 <-> perf:Chopin_Ashkenazy:cpt1@96.1),
#  MatchClaim(instant: score:clt1@88.0 <-> perf:Chopin_Ashkenazy:cpt1@96.5),
#  MatchClaim(instant: score:clt1@88.5 <-> perf:Chopin_Ashkenazy:cpt1@96.9),
#  MatchClaim(instant: score:clt1@89.0 <-> perf:Chopin_Ashkenazy:cpt1@97.4),
#  MatchClaim(instant: score:clt1@89.5 <-> perf:Chopin_Ashkenazy:cpt1@97.8),
#  MatchClaim(instant: score:clt1@90.0 <-> perf:Chopin_Ashkenazy:cpt1@98.2),
#  MatchClaim(instant: score:clt1@90.5 <-> perf:Chopin_Ashkenazy:cpt1@98.7),
#  MatchClaim(instant: score:clt1@91.0 <-> perf:Chopin_Ashkenazy:cpt1@99.4),
#  MatchClaim(instant: score:clt1@91.5 <-> perf:Chopin_Ashkenazy:cpt1@100.0),
#  MatchClaim(instant: score:clt1@92.0 <-> perf:Chopin_Ashkenazy:cpt1@100.5),
#  MatchClaim(instant: score:clt1@92.1 <-> perf:Chopin_Ashkenazy:cpt1@100.8),
#  MatchClaim(instant: score:clt1@92.2 <-> perf:Chopin_Ashkenazy:cpt1@100.9),
#  MatchClaim(instant: score:clt1@92.4 <-> perf:Chopin_Ashkenazy:cpt1@101.1),
#  MatchClaim(instant: score:clt1@92.5 <-> perf:Chopin_Ashkenazy:cpt1@101.2),
#  MatchClaim(instant: score:clt1@92.6 <-> perf:Chopin_Ashkenazy:cpt1@101.3),
#  MatchClaim(instant: score:clt1@92.8 <-> perf:Chopin_Ashkenazy:cpt1@101.5),
#  MatchClaim(instant: score:clt1@92.9 <-> perf:Chopin_Ashkenazy:cpt1@101.6),
#  MatchClaim(instant: score:clt1@93.0 <-> perf:Chopin_Ashkenazy:cpt1@101.8),
#  MatchClaim(instant: score:clt1@93.1 <-> perf:Chopin_Ashkenazy:cpt1@102.0),
#  MatchClaim(instant: score:clt1@93.2 <-> perf:Chopin_Ashkenazy:cpt1@102.4),
#  MatchClaim(instant: score:clt1@93.3 <-> perf:Chopin_Ashkenazy:cpt1@102.5),
#  MatchClaim(instant: score:clt1@93.4 <-> perf:Chopin_Ashkenazy:cpt1@102.6),
#  MatchClaim(instant: score:clt1@93.4 <-> perf:Chopin_Ashkenazy:cpt1@102.8),
#  MatchClaim(instant: score:clt1@93.5 <-> perf:Chopin_Ashkenazy:cpt1@103.1),
#  MatchClaim(instant: score:clt1@94.0 <-> perf:Chopin_Ashkenazy:cpt1@103.7),
#  MatchClaim(instant: score:clt1@94.5 <-> perf:Chopin_Ashkenazy:cpt1@104.2),
#  MatchClaim(instant: score:clt1@95.0 <-> perf:Chopin_Ashkenazy:cpt1@104.6),
#  MatchClaim(instant: score:clt1@95.5 <-> perf:Chopin_Ashkenazy:cpt1@105.1),
#  MatchClaim(instant: score:clt1@96.0 <-> perf:Chopin_Ashkenazy:cpt1@105.7),
#  MatchClaim(instant: score:clt1@96.5 <-> perf:Chopin_Ashkenazy:cpt1@106.4),
#  MatchClaim(instant: score:clt1@97.0 <-> perf:Chopin_Ashkenazy:cpt1@107.0),
#  MatchClaim(instant: score:clt1@97.5 <-> perf:Chopin_Ashkenazy:cpt1@107.4),
#  MatchClaim(instant: score:clt1@98.0 <-> perf:Chopin_Ashkenazy:cpt1@107.9),
#  MatchClaim(instant: score:clt1@98.5 <-> perf:Chopin_Ashkenazy:cpt1@108.3),
#  MatchClaim(instant: score:clt1@99.0 <-> perf:Chopin_Ashkenazy:cpt1@108.7),
#  MatchClaim(instant: score:clt1@99.5 <-> perf:Chopin_Ashkenazy:cpt1@109.2),
#  MatchClaim(instant: score:clt1@100.0 <-> perf:Chopin_Ashkenazy:cpt1@109.6),
#  MatchClaim(instant: score:clt1@100.5 <-> perf:Chopin_Ashkenazy:cpt1@110.0),
#  MatchClaim(instant: score:clt1@101.0 <-> perf:Chopin_Ashkenazy:cpt1@110.4),
#  MatchClaim(instant: score:clt1@101.5 <-> perf:Chopin_Ashkenazy:cpt1@110.8),
#  MatchClaim(instant: score:clt1@102.0 <-> perf:Chopin_Ashkenazy:cpt1@111.2),
#  MatchClaim(instant: score:clt1@102.5 <-> perf:Chopin_Ashkenazy:cpt1@111.9),
#  MatchClaim(instant: score:clt1@102.9 <-> perf:Chopin_Ashkenazy:cpt1@112.3),
#  MatchClaim(instant: score:clt1@103.0 <-> perf:Chopin_Ashkenazy:cpt1@112.4),
#  MatchClaim(instant: score:clt1@103.2 <-> perf:Chopin_Ashkenazy:cpt1@112.7),
#  MatchClaim(instant: score:clt1@103.5 <-> perf:Chopin_Ashkenazy:cpt1@112.9),
#  MatchClaim(instant: score:clt1@103.6 <-> perf:Chopin_Ashkenazy:cpt1@113.0),
#  MatchClaim(instant: score:clt1@104.0 <-> perf:Chopin_Ashkenazy:cpt1@113.4),
#  MatchClaim(instant: score:clt1@104.5 <-> perf:Chopin_Ashkenazy:cpt1@113.9),
#  MatchClaim(instant: score:clt1@104.8 <-> perf:Chopin_Ashkenazy:cpt1@114.2),
#  MatchClaim(instant: score:clt1@105.0 <-> perf:Chopin_Ashkenazy:cpt1@114.6),
#  MatchClaim(instant: score:clt1@105.4 <-> perf:Chopin_Ashkenazy:cpt1@115.4),
#  MatchClaim(instant: score:clt1@105.5 <-> perf:Chopin_Ashkenazy:cpt1@115.7),
#  MatchClaim(instant: score:clt1@106.0 <-> perf:Chopin_Ashkenazy:cpt1@116.3),
#  MatchClaim(instant: score:clt1@106.5 <-> perf:Chopin_Ashkenazy:cpt1@116.7),
#  MatchClaim(instant: score:clt1@107.0 <-> perf:Chopin_Ashkenazy:cpt1@117.1),
#  MatchClaim(instant: score:clt1@107.5 <-> perf:Chopin_Ashkenazy:cpt1@117.5),
#  MatchClaim(instant: score:clt1@108.0 <-> perf:Chopin_Ashkenazy:cpt1@117.9),
#  MatchClaim(instant: score:clt1@108.5 <-> perf:Chopin_Ashkenazy:cpt1@118.4),
#  MatchClaim(instant: score:clt1@109.0 <-> perf:Chopin_Ashkenazy:cpt1@118.9),
#  MatchClaim(instant: score:clt1@109.5 <-> perf:Chopin_Ashkenazy:cpt1@119.3),
#  MatchClaim(instant: score:clt1@110.0 <-> perf:Chopin_Ashkenazy:cpt1@119.7),
#  MatchClaim(instant: score:clt1@110.5 <-> perf:Chopin_Ashkenazy:cpt1@120.1),
#  MatchClaim(instant: score:clt1@111.0 <-> perf:Chopin_Ashkenazy:cpt1@120.5),
#  MatchClaim(instant: score:clt1@111.5 <-> perf:Chopin_Ashkenazy:cpt1@120.9),
#  MatchClaim(instant: score:clt1@112.0 <-> perf:Chopin_Ashkenazy:cpt1@121.3),
#  MatchClaim(instant: score:clt1@112.5 <-> perf:Chopin_Ashkenazy:cpt1@121.7),
#  MatchClaim(instant: score:clt1@113.0 <-> perf:Chopin_Ashkenazy:cpt1@122.1),
#  MatchClaim(instant: score:clt1@113.5 <-> perf:Chopin_Ashkenazy:cpt1@122.5),
#  MatchClaim(instant: score:clt1@114.0 <-> perf:Chopin_Ashkenazy:cpt1@122.9),
#  MatchClaim(instant: score:clt1@114.5 <-> perf:Chopin_Ashkenazy:cpt1@123.4),
#  MatchClaim(instant: score:clt1@115.0 <-> perf:Chopin_Ashkenazy:cpt1@123.9),
#  MatchClaim(instant: score:clt1@115.5 <-> perf:Chopin_Ashkenazy:cpt1@124.3),
#  MatchClaim(instant: score:clt1@116.0 <-> perf:Chopin_Ashkenazy:cpt1@124.8),
#  MatchClaim(instant: score:clt1@116.5 <-> perf:Chopin_Ashkenazy:cpt1@125.3),
#  MatchClaim(instant: score:clt1@117.0 <-> perf:Chopin_Ashkenazy:cpt1@125.7),
#  MatchClaim(instant: score:clt1@117.5 <-> perf:Chopin_Ashkenazy:cpt1@126.3),
#  MatchClaim(instant: score:clt1@118.0 <-> perf:Chopin_Ashkenazy:cpt1@127.2),
#  MatchClaim(instant: score:clt1@118.5 <-> perf:Chopin_Ashkenazy:cpt1@127.9),
#  MatchClaim(instant: score:clt1@119.0 <-> perf:Chopin_Ashkenazy:cpt1@128.4),
#  MatchClaim(instant: score:clt1@119.5 <-> perf:Chopin_Ashkenazy:cpt1@129.0),
#  MatchClaim(instant: score:clt1@120.0 <-> perf:Chopin_Ashkenazy:cpt1@129.7),
#  MatchClaim(instant: score:clt1@120.5 <-> perf:Chopin_Ashkenazy:cpt1@130.7),
#  MatchClaim(instant: score:clt1@121.0 <-> perf:Chopin_Ashkenazy:cpt1@131.6),
#  MatchClaim(instant: score:clt1@121.5 <-> perf:Chopin_Ashkenazy:cpt1@132.2),
#  MatchClaim(instant: score:clt1@121.8 <-> perf:Chopin_Ashkenazy:cpt1@132.5),
#  MatchClaim(instant: score:clt1@122.0 <-> perf:Chopin_Ashkenazy:cpt1@132.8),
#  MatchClaim(instant: score:clt1@122.2 <-> perf:Chopin_Ashkenazy:cpt1@133.0),
#  MatchClaim(instant: score:clt1@122.5 <-> perf:Chopin_Ashkenazy:cpt1@133.2),
#  MatchClaim(instant: score:clt1@122.8 <-> perf:Chopin_Ashkenazy:cpt1@133.5),
#  MatchClaim(instant: score:clt1@123.0 <-> perf:Chopin_Ashkenazy:cpt1@133.9),
#  MatchClaim(instant: score:clt1@123.4 <-> perf:Chopin_Ashkenazy:cpt1@134.5),
#  MatchClaim(instant: score:clt1@123.5 <-> perf:Chopin_Ashkenazy:cpt1@134.7),
#  MatchClaim(instant: score:clt1@124.0 <-> perf:Chopin_Ashkenazy:cpt1@135.2),
#  MatchClaim(instant: score:clt1@124.5 <-> perf:Chopin_Ashkenazy:cpt1@135.8),
#  MatchClaim(instant: score:clt1@125.0 <-> perf:Chopin_Ashkenazy:cpt1@136.3),
#  MatchClaim(instant: score:clt1@125.2 <-> perf:Chopin_Ashkenazy:cpt1@136.6),
#  MatchClaim(instant: score:clt1@125.5 <-> perf:Chopin_Ashkenazy:cpt1@136.8),
#  MatchClaim(instant: score:clt1@125.8 <-> perf:Chopin_Ashkenazy:cpt1@137.0),
#  MatchClaim(instant: score:clt1@126.0 <-> perf:Chopin_Ashkenazy:cpt1@137.3),
#  MatchClaim(instant: score:clt1@126.2 <-> perf:Chopin_Ashkenazy:cpt1@137.5),
#  MatchClaim(instant: score:clt1@126.5 <-> perf:Chopin_Ashkenazy:cpt1@137.7),
#  MatchClaim(instant: score:clt1@126.8 <-> perf:Chopin_Ashkenazy:cpt1@137.9),
#  MatchClaim(instant: score:clt1@127.0 <-> perf:Chopin_Ashkenazy:cpt1@138.2),
#  MatchClaim(instant: score:clt1@127.2 <-> perf:Chopin_Ashkenazy:cpt1@138.4),
#  MatchClaim(instant: score:clt1@127.5 <-> perf:Chopin_Ashkenazy:cpt1@138.6),
#  MatchClaim(instant: score:clt1@127.8 <-> perf:Chopin_Ashkenazy:cpt1@138.7),
#  MatchClaim(instant: score:clt1@128.0 <-> perf:Chopin_Ashkenazy:cpt1@139.0),
#  MatchClaim(instant: score:clt1@128.2 <-> perf:Chopin_Ashkenazy:cpt1@139.1),
#  MatchClaim(instant: score:clt1@128.5 <-> perf:Chopin_Ashkenazy:cpt1@139.4),
#  MatchClaim(instant: score:clt1@128.8 <-> perf:Chopin_Ashkenazy:cpt1@139.8),
#  MatchClaim(instant: score:clt1@129.0 <-> perf:Chopin_Ashkenazy:cpt1@140.2),
#  MatchClaim(instant: score:clt1@129.2 <-> perf:Chopin_Ashkenazy:cpt1@140.5),
#  MatchClaim(instant: score:clt1@129.5 <-> perf:Chopin_Ashkenazy:cpt1@141.1),
#  MatchClaim(instant: score:clt1@130.0 <-> perf:Chopin_Ashkenazy:cpt1@141.8),
#  MatchClaim(instant: score:clt1@130.5 <-> perf:Chopin_Ashkenazy:cpt1@142.3),
#  MatchClaim(instant: score:clt1@131.0 <-> perf:Chopin_Ashkenazy:cpt1@142.8),
#  MatchClaim(instant: score:clt1@131.5 <-> perf:Chopin_Ashkenazy:cpt1@143.4),
#  MatchClaim(instant: score:clt1@132.0 <-> perf:Chopin_Ashkenazy:cpt1@143.8),
#  MatchClaim(instant: score:clt1@132.5 <-> perf:Chopin_Ashkenazy:cpt1@144.4),
#  MatchClaim(instant: score:clt1@133.0 <-> perf:Chopin_Ashkenazy:cpt1@144.8),
#  MatchClaim(instant: score:clt1@133.5 <-> perf:Chopin_Ashkenazy:cpt1@145.3),
#  MatchClaim(instant: score:clt1@134.0 <-> perf:Chopin_Ashkenazy:cpt1@145.9),
#  MatchClaim(instant: score:clt1@134.5 <-> perf:Chopin_Ashkenazy:cpt1@146.5),
#  MatchClaim(instant: score:clt1@135.0 <-> perf:Chopin_Ashkenazy:cpt1@147.0),
#  MatchClaim(instant: score:clt1@135.5 <-> perf:Chopin_Ashkenazy:cpt1@147.5),
#  MatchClaim(instant: score:clt1@136.0 <-> perf:Chopin_Ashkenazy:cpt1@148.0),
#  MatchClaim(instant: score:clt1@136.5 <-> perf:Chopin_Ashkenazy:cpt1@148.4),
#  MatchClaim(instant: score:clt1@137.0 <-> perf:Chopin_Ashkenazy:cpt1@148.9),
#  MatchClaim(instant: score:clt1@137.5 <-> perf:Chopin_Ashkenazy:cpt1@149.4),
#  MatchClaim(instant: score:clt1@138.0 <-> perf:Chopin_Ashkenazy:cpt1@149.8),
#  MatchClaim(instant: score:clt1@138.5 <-> perf:Chopin_Ashkenazy:cpt1@150.5),
#  MatchClaim(instant: score:clt1@138.8 <-> perf:Chopin_Ashkenazy:cpt1@151.2),
#  MatchClaim(instant: score:clt1@139.0 <-> perf:Chopin_Ashkenazy:cpt1@151.5),
#  MatchClaim(instant: score:clt1@139.2 <-> perf:Chopin_Ashkenazy:cpt1@152.0),
#  MatchClaim(instant: score:clt1@139.5 <-> perf:Chopin_Ashkenazy:cpt1@152.5),
#  MatchClaim(instant: score:clt1@139.8 <-> perf:Chopin_Ashkenazy:cpt1@152.9),
#  MatchClaim(instant: score:clt1@140.0 <-> perf:Chopin_Ashkenazy:cpt1@153.2),
#  MatchClaim(instant: score:clt1@140.2 <-> perf:Chopin_Ashkenazy:cpt1@153.4),
#  MatchClaim(instant: score:clt1@140.5 <-> perf:Chopin_Ashkenazy:cpt1@153.7),
#  MatchClaim(instant: score:clt1@140.8 <-> perf:Chopin_Ashkenazy:cpt1@153.9),
#  MatchClaim(instant: score:clt1@140.8 <-> perf:Chopin_Ashkenazy:cpt1@154.0),
#  MatchClaim(instant: score:clt1@140.9 <-> perf:Chopin_Ashkenazy:cpt1@154.2),
#  MatchClaim(instant: score:clt1@140.9 <-> perf:Chopin_Ashkenazy:cpt1@154.3),
#  MatchClaim(instant: score:clt1@141.0 <-> perf:Chopin_Ashkenazy:cpt1@154.5),
#  MatchClaim(instant: score:clt1@141.1 <-> perf:Chopin_Ashkenazy:cpt1@154.8),
#  MatchClaim(instant: score:clt1@141.2 <-> perf:Chopin_Ashkenazy:cpt1@155.2),
#  MatchClaim(instant: score:clt1@141.3 <-> perf:Chopin_Ashkenazy:cpt1@155.5),
#  MatchClaim(instant: score:clt1@141.4 <-> perf:Chopin_Ashkenazy:cpt1@155.6),
#  MatchClaim(instant: score:clt1@141.4 <-> perf:Chopin_Ashkenazy:cpt1@155.7),
#  MatchClaim(instant: score:clt1@141.5 <-> perf:Chopin_Ashkenazy:cpt1@156.2),
#  MatchClaim(instant: score:clt1@142.0 <-> perf:Chopin_Ashkenazy:cpt1@156.8),
#  MatchClaim(instant: score:clt1@142.5 <-> perf:Chopin_Ashkenazy:cpt1@157.3),
#  MatchClaim(instant: score:clt1@143.0 <-> perf:Chopin_Ashkenazy:cpt1@157.7),
#  MatchClaim(instant: score:clt1@143.5 <-> perf:Chopin_Ashkenazy:cpt1@158.2),
#  MatchClaim(instant: score:clt1@144.0 <-> perf:Chopin_Ashkenazy:cpt1@158.8),
#  MatchClaim(instant: score:clt1@144.5 <-> perf:Chopin_Ashkenazy:cpt1@159.6),
#  MatchClaim(instant: score:clt1@145.0 <-> perf:Chopin_Ashkenazy:cpt1@160.3),
#  MatchClaim(instant: score:clt1@145.5 <-> perf:Chopin_Ashkenazy:cpt1@161.1),
#  MatchClaim(instant: score:clt1@146.0 <-> perf:Chopin_Ashkenazy:cpt1@161.8),
#  MatchClaim(instant: score:clt1@146.5 <-> perf:Chopin_Ashkenazy:cpt1@162.3),
#  MatchClaim(instant: score:clt1@147.0 <-> perf:Chopin_Ashkenazy:cpt1@162.9),
#  MatchClaim(instant: score:clt1@147.5 <-> perf:Chopin_Ashkenazy:cpt1@163.6),
#  MatchClaim(instant: score:clt1@148.0 <-> perf:Chopin_Ashkenazy:cpt1@164.4),
#  MatchClaim(instant: score:clt1@148.5 <-> perf:Chopin_Ashkenazy:cpt1@164.9),
#  MatchClaim(instant: score:clt1@149.0 <-> perf:Chopin_Ashkenazy:cpt1@165.3),
#  MatchClaim(instant: score:clt1@149.5 <-> perf:Chopin_Ashkenazy:cpt1@165.8),
#  MatchClaim(instant: score:clt1@150.0 <-> perf:Chopin_Ashkenazy:cpt1@166.3),
#  MatchClaim(instant: score:clt1@150.5 <-> perf:Chopin_Ashkenazy:cpt1@167.2),
#  MatchClaim(instant: score:clt1@151.0 <-> perf:Chopin_Ashkenazy:cpt1@167.9),
#  MatchClaim(instant: score:clt1@151.5 <-> perf:Chopin_Ashkenazy:cpt1@168.4),
#  MatchClaim(instant: score:clt1@152.0 <-> perf:Chopin_Ashkenazy:cpt1@168.9),
#  MatchClaim(instant: score:clt1@152.2 <-> perf:Chopin_Ashkenazy:cpt1@169.2),
#  MatchClaim(instant: score:clt1@152.5 <-> perf:Chopin_Ashkenazy:cpt1@169.5),
#  MatchClaim(instant: score:clt1@152.8 <-> perf:Chopin_Ashkenazy:cpt1@169.8),
#  MatchClaim(instant: score:clt1@153.0 <-> perf:Chopin_Ashkenazy:cpt1@170.0),
#  MatchClaim(instant: score:clt1@153.2 <-> perf:Chopin_Ashkenazy:cpt1@170.3),
#  MatchClaim(instant: score:clt1@153.5 <-> perf:Chopin_Ashkenazy:cpt1@170.6),
#  MatchClaim(instant: score:clt1@154.0 <-> perf:Chopin_Ashkenazy:cpt1@171.2),
#  MatchClaim(instant: score:clt1@154.5 <-> perf:Chopin_Ashkenazy:cpt1@171.8),
#  MatchClaim(instant: score:clt1@155.0 <-> perf:Chopin_Ashkenazy:cpt1@173.0),
#  MatchClaim(instant: score:clt1@155.5 <-> perf:Chopin_Ashkenazy:cpt1@173.7),
#  MatchClaim(instant: score:clt1@156.0 <-> perf:Chopin_Ashkenazy:cpt1@174.2),
#  MatchClaim(instant: score:clt1@156.5 <-> perf:Chopin_Ashkenazy:cpt1@174.8),
#  MatchClaim(instant: score:clt1@157.0 <-> perf:Chopin_Ashkenazy:cpt1@175.4),
#  MatchClaim(instant: score:clt1@157.5 <-> perf:Chopin_Ashkenazy:cpt1@175.8),
#  MatchClaim(instant: score:clt1@158.0 <-> perf:Chopin_Ashkenazy:cpt1@176.3),
#  MatchClaim(instant: score:clt1@158.5 <-> perf:Chopin_Ashkenazy:cpt1@176.7),
#  MatchClaim(instant: score:clt1@159.0 <-> perf:Chopin_Ashkenazy:cpt1@177.1),
#  MatchClaim(instant: score:clt1@159.5 <-> perf:Chopin_Ashkenazy:cpt1@177.6),
#  MatchClaim(instant: score:clt1@160.0 <-> perf:Chopin_Ashkenazy:cpt1@178.1),
#  MatchClaim(instant: score:clt1@160.2 <-> perf:Chopin_Ashkenazy:cpt1@178.3),
#  MatchClaim(instant: score:clt1@160.5 <-> perf:Chopin_Ashkenazy:cpt1@178.6),
#  MatchClaim(instant: score:clt1@160.8 <-> perf:Chopin_Ashkenazy:cpt1@178.8),
#  MatchClaim(instant: score:clt1@161.0 <-> perf:Chopin_Ashkenazy:cpt1@179.6),
#  MatchClaim(instant: score:clt1@161.5 <-> perf:Chopin_Ashkenazy:cpt1@180.4),
#  MatchClaim(instant: score:clt1@161.8 <-> perf:Chopin_Ashkenazy:cpt1@180.7),
#  MatchClaim(instant: score:clt1@162.0 <-> perf:Chopin_Ashkenazy:cpt1@181.0),
#  MatchClaim(instant: score:clt1@162.2 <-> perf:Chopin_Ashkenazy:cpt1@181.2),
#  MatchClaim(instant: score:clt1@162.5 <-> perf:Chopin_Ashkenazy:cpt1@181.6),
#  MatchClaim(instant: score:clt1@163.0 <-> perf:Chopin_Ashkenazy:cpt1@182.1),
#  MatchClaim(instant: score:clt1@163.5 <-> perf:Chopin_Ashkenazy:cpt1@182.7),
#  MatchClaim(instant: score:clt1@164.0 <-> perf:Chopin_Ashkenazy:cpt1@183.3),
#  MatchClaim(instant: score:clt1@164.2 <-> perf:Chopin_Ashkenazy:cpt1@183.6),
#  MatchClaim(instant: score:clt1@164.5 <-> perf:Chopin_Ashkenazy:cpt1@183.9),
#  MatchClaim(instant: score:clt1@164.8 <-> perf:Chopin_Ashkenazy:cpt1@184.2),
#  MatchClaim(instant: score:clt1@165.0 <-> perf:Chopin_Ashkenazy:cpt1@184.8),
#  MatchClaim(instant: score:clt1@165.4 <-> perf:Chopin_Ashkenazy:cpt1@185.6),
#  MatchClaim(instant: score:clt1@165.5 <-> perf:Chopin_Ashkenazy:cpt1@185.9),
#  MatchClaim(instant: score:clt1@166.0 <-> perf:Chopin_Ashkenazy:cpt1@186.6),
#  MatchClaim(instant: score:clt1@166.5 <-> perf:Chopin_Ashkenazy:cpt1@187.1),
#  MatchClaim(instant: score:clt1@167.0 <-> perf:Chopin_Ashkenazy:cpt1@187.6),
#  MatchClaim(instant: score:clt1@167.5 <-> perf:Chopin_Ashkenazy:cpt1@188.1),
#  MatchClaim(instant: score:clt1@168.0 <-> perf:Chopin_Ashkenazy:cpt1@188.6),
#  MatchClaim(instant: score:clt1@168.5 <-> perf:Chopin_Ashkenazy:cpt1@189.5),
#  MatchClaim(instant: score:clt1@169.0 <-> perf:Chopin_Ashkenazy:cpt1@190.4),
#  MatchClaim(instant: score:clt1@169.5 <-> perf:Chopin_Ashkenazy:cpt1@190.8),
#  MatchClaim(instant: score:clt1@170.0 <-> perf:Chopin_Ashkenazy:cpt1@191.4),
#  MatchClaim(instant: score:clt1@170.2 <-> perf:Chopin_Ashkenazy:cpt1@191.7),
#  MatchClaim(instant: score:clt1@170.4 <-> perf:Chopin_Ashkenazy:cpt1@191.8),
#  MatchClaim(instant: score:clt1@170.5 <-> perf:Chopin_Ashkenazy:cpt1@191.9),
#  MatchClaim(instant: score:clt1@170.6 <-> perf:Chopin_Ashkenazy:cpt1@192.0),
#  MatchClaim(instant: score:clt1@170.8 <-> perf:Chopin_Ashkenazy:cpt1@192.3),
#  MatchClaim(instant: score:clt1@170.9 <-> perf:Chopin_Ashkenazy:cpt1@192.5),
#  MatchClaim(instant: score:clt1@171.0 <-> perf:Chopin_Ashkenazy:cpt1@192.6),
#  MatchClaim(instant: score:clt1@171.1 <-> perf:Chopin_Ashkenazy:cpt1@192.9),
#  MatchClaim(instant: score:clt1@171.3 <-> perf:Chopin_Ashkenazy:cpt1@193.0),
#  MatchClaim(instant: score:clt1@171.5 <-> perf:Chopin_Ashkenazy:cpt1@193.4),
#  MatchClaim(instant: score:clt1@172.0 <-> perf:Chopin_Ashkenazy:cpt1@193.9),
#  MatchClaim(instant: score:clt1@172.5 <-> perf:Chopin_Ashkenazy:cpt1@194.4),
#  MatchClaim(instant: score:clt1@173.0 <-> perf:Chopin_Ashkenazy:cpt1@194.8),
#  MatchClaim(instant: score:clt1@173.5 <-> perf:Chopin_Ashkenazy:cpt1@195.2),
#  MatchClaim(instant: score:clt1@174.0 <-> perf:Chopin_Ashkenazy:cpt1@195.6),
#  MatchClaim(instant: score:clt1@174.5 <-> perf:Chopin_Ashkenazy:cpt1@196.2),
#  MatchClaim(instant: score:clt1@175.0 <-> perf:Chopin_Ashkenazy:cpt1@196.8),
#  MatchClaim(instant: score:clt1@175.2 <-> perf:Chopin_Ashkenazy:cpt1@197.0),
#  MatchClaim(instant: score:clt1@175.5 <-> perf:Chopin_Ashkenazy:cpt1@197.2),
#  MatchClaim(instant: score:clt1@175.8 <-> perf:Chopin_Ashkenazy:cpt1@197.4),
#  MatchClaim(instant: score:clt1@176.0 <-> perf:Chopin_Ashkenazy:cpt1@197.6),
#  MatchClaim(instant: score:clt1@176.2 <-> perf:Chopin_Ashkenazy:cpt1@197.8),
#  MatchClaim(instant: score:clt1@176.5 <-> perf:Chopin_Ashkenazy:cpt1@198.0),
#  MatchClaim(instant: score:clt1@176.8 <-> perf:Chopin_Ashkenazy:cpt1@198.2),
#  MatchClaim(instant: score:clt1@177.0 <-> perf:Chopin_Ashkenazy:cpt1@198.4),
#  MatchClaim(instant: score:clt1@177.2 <-> perf:Chopin_Ashkenazy:cpt1@198.8),
#  MatchClaim(instant: score:clt1@177.4 <-> perf:Chopin_Ashkenazy:cpt1@198.9),
#  MatchClaim(instant: score:clt1@177.5 <-> perf:Chopin_Ashkenazy:cpt1@199.0),
#  MatchClaim(instant: score:clt1@178.0 <-> perf:Chopin_Ashkenazy:cpt1@199.6),
#  MatchClaim(instant: score:clt1@178.5 <-> perf:Chopin_Ashkenazy:cpt1@200.2),
#  MatchClaim(instant: score:clt1@179.0 <-> perf:Chopin_Ashkenazy:cpt1@200.6),
#  MatchClaim(instant: score:clt1@179.5 <-> perf:Chopin_Ashkenazy:cpt1@201.0),
#  MatchClaim(instant: score:clt1@180.0 <-> perf:Chopin_Ashkenazy:cpt1@201.4),
#  MatchClaim(instant: score:clt1@180.5 <-> perf:Chopin_Ashkenazy:cpt1@201.8),
#  MatchClaim(instant: score:clt1@181.0 <-> perf:Chopin_Ashkenazy:cpt1@202.1),
#  MatchClaim(instant: score:clt1@181.5 <-> perf:Chopin_Ashkenazy:cpt1@202.4),
#  MatchClaim(instant: score:clt1@182.0 <-> perf:Chopin_Ashkenazy:cpt1@202.8),
#  MatchClaim(instant: score:clt1@182.5 <-> perf:Chopin_Ashkenazy:cpt1@203.2),
#  MatchClaim(instant: score:clt1@183.0 <-> perf:Chopin_Ashkenazy:cpt1@203.5),
#  MatchClaim(instant: score:clt1@183.5 <-> perf:Chopin_Ashkenazy:cpt1@203.9),
#  MatchClaim(instant: score:clt1@184.0 <-> perf:Chopin_Ashkenazy:cpt1@204.4),
#  MatchClaim(instant: score:clt1@184.5 <-> perf:Chopin_Ashkenazy:cpt1@204.9),
#  MatchClaim(instant: score:clt1@185.0 <-> perf:Chopin_Ashkenazy:cpt1@205.2),
#  MatchClaim(instant: score:clt1@185.5 <-> perf:Chopin_Ashkenazy:cpt1@205.7),
#  MatchClaim(instant: score:clt1@186.0 <-> perf:Chopin_Ashkenazy:cpt1@206.3),
#  MatchClaim(instant: score:clt1@186.5 <-> perf:Chopin_Ashkenazy:cpt1@207.0),
#  MatchClaim(instant: score:clt1@186.9 <-> perf:Chopin_Ashkenazy:cpt1@207.5),
#  MatchClaim(instant: score:clt1@187.2 <-> perf:Chopin_Ashkenazy:cpt1@207.7),
#  MatchClaim(instant: score:clt1@187.6 <-> perf:Chopin_Ashkenazy:cpt1@208.0),
#  MatchClaim(instant: score:clt1@188.0 <-> perf:Chopin_Ashkenazy:cpt1@208.1),
#  MatchClaim(instant: score:clt1@188.4 <-> perf:Chopin_Ashkenazy:cpt1@208.3),
#  MatchClaim(instant: score:clt1@188.8 <-> perf:Chopin_Ashkenazy:cpt1@208.5),
#  MatchClaim(instant: score:clt1@189.1 <-> perf:Chopin_Ashkenazy:cpt1@208.8),
#  MatchClaim(instant: score:clt1@189.5 <-> perf:Chopin_Ashkenazy:cpt1@209.1),
#  MatchClaim(score:clt1@192.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@192.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@192.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@192.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@193.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@194.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@195.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@196.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@197.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@198.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.6 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.8 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@199.9 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@200.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@200.1 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@200.2 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@200.4 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@200.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@201.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@201.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@202.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@202.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@203.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@203.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@204.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@204.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@205.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@205.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@206.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@206.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@208.0 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(score:clt1@209.5 <-> perf:Chopin_Ashkenazy:cpt1 [NOMATCH]),
#  MatchClaim(instant: score:clt1@0.5 <-> perf:Chopin_Ashkenazy:cpt1@10.3),
#  MatchClaim(instant: score:clt1@6.5 <-> perf:Chopin_Ashkenazy:cpt1@16.2),
#  MatchClaim(instant: score:clt1@12.5 <-> perf:Chopin_Ashkenazy:cpt1@21.5),
#  MatchClaim(instant: score:clt1@18.5 <-> perf:Chopin_Ashkenazy:cpt1@26.3),
#  MatchClaim(instant: score:clt1@24.5 <-> perf:Chopin_Ashkenazy:cpt1@32.7),
#  MatchClaim(instant: score:clt1@30.5 <-> perf:Chopin_Ashkenazy:cpt1@38.8),
#  MatchClaim(instant: score:clt1@36.5 <-> perf:Chopin_Ashkenazy:cpt1@44.3),
#  MatchClaim(instant: score:clt1@42.5 <-> perf:Chopin_Ashkenazy:cpt1@49.6),
#  MatchClaim(instant: score:clt1@48.5 <-> perf:Chopin_Ashkenazy:cpt1@56.6),
#  MatchClaim(instant: score:clt1@54.5 <-> perf:Chopin_Ashkenazy:cpt1@62.8),
#  MatchClaim(instant: score:clt1@60.5 <-> perf:Chopin_Ashkenazy:cpt1@69.4),
#  MatchClaim(instant: score:clt1@66.5 <-> perf:Chopin_Ashkenazy:cpt1@74.2),
#  MatchClaim(instant: score:clt1@72.5 <-> perf:Chopin_Ashkenazy:cpt1@80.6),
#  MatchClaim(instant: score:clt1@78.5 <-> perf:Chopin_Ashkenazy:cpt1@87.6),
#  MatchClaim(instant: score:clt1@84.5 <-> perf:Chopin_Ashkenazy:cpt1@93.2),
#  MatchClaim(instant: score:clt1@90.5 <-> perf:Chopin_Ashkenazy:cpt1@98.7),
#  MatchClaim(instant: score:clt1@96.5 <-> perf:Chopin_Ashkenazy:cpt1@106.4),
#  MatchClaim(instant: score:clt1@102.5 <-> perf:Chopin_Ashkenazy:cpt1@111.9),
#  MatchClaim(instant: score:clt1@108.5 <-> perf:Chopin_Ashkenazy:cpt1@118.4),
#  MatchClaim(instant: score:clt1@114.5 <-> perf:Chopin_Ashkenazy:cpt1@123.4),
#  MatchClaim(instant: score:clt1@120.5 <-> perf:Chopin_Ashkenazy:cpt1@130.7),
#  MatchClaim(instant: score:clt1@126.5 <-> perf:Chopin_Ashkenazy:cpt1@137.7),
#  MatchClaim(instant: score:clt1@132.5 <-> perf:Chopin_Ashkenazy:cpt1@144.4),
#  MatchClaim(instant: score:clt1@138.5 <-> perf:Chopin_Ashkenazy:cpt1@150.5),
#  MatchClaim(instant: score:clt1@144.5 <-> perf:Chopin_Ashkenazy:cpt1@159.6),
#  MatchClaim(instant: score:clt1@150.5 <-> perf:Chopin_Ashkenazy:cpt1@167.2),
#  MatchClaim(instant: score:clt1@156.5 <-> perf:Chopin_Ashkenazy:cpt1@174.8),
#  MatchClaim(instant: score:clt1@162.5 <-> perf:Chopin_Ashkenazy:cpt1@181.6),
#  MatchClaim(instant: score:clt1@168.5 <-> perf:Chopin_Ashkenazy:cpt1@189.5),
#  MatchClaim(instant: score:clt1@174.5 <-> perf:Chopin_Ashkenazy:cpt1@196.2),
#  MatchClaim(instant: score:clt1@180.5 <-> perf:Chopin_Ashkenazy:cpt1@201.8),
#  MatchClaim(instant: score:clt1@186.5 <-> perf:Chopin_Ashkenazy:cpt1@207.0),
#  MatchClaim(instant: score:clt1@0.0 <-> perf:Chopin_Ashkenazy:cpt1@9.5),
#  MatchClaim(instant: score:clt1@0.5 <-> perf:Chopin_Ashkenazy:cpt1@10.3),
#  MatchClaim(instant: score:clt1@1.0 <-> perf:Chopin_Ashkenazy:cpt1@11.1),
#  MatchClaim(instant: score:clt1@1.5 <-> perf:Chopin_Ashkenazy:cpt1@11.6),
#  MatchClaim(instant: score:clt1@2.0 <-> perf:Chopin_Ashkenazy:cpt1@12.0),
#  MatchClaim(instant: score:clt1@2.5 <-> perf:Chopin_Ashkenazy:cpt1@12.4),
#  MatchClaim(instant: score:clt1@3.0 <-> perf:Chopin_Ashkenazy:cpt1@12.9),
#  MatchClaim(instant: score:clt1@3.5 <-> perf:Chopin_Ashkenazy:cpt1@13.4),
#  MatchClaim(instant: score:clt1@4.0 <-> perf:Chopin_Ashkenazy:cpt1@13.9),
#  MatchClaim(instant: score:clt1@4.5 <-> perf:Chopin_Ashkenazy:cpt1@14.4),
#  MatchClaim(instant: score:clt1@5.0 <-> perf:Chopin_Ashkenazy:cpt1@14.8),
#  MatchClaim(instant: score:clt1@5.5 <-> perf:Chopin_Ashkenazy:cpt1@15.2),
#  MatchClaim(instant: score:clt1@6.0 <-> perf:Chopin_Ashkenazy:cpt1@15.6),
#  MatchClaim(instant: score:clt1@6.5 <-> perf:Chopin_Ashkenazy:cpt1@16.2),
#  MatchClaim(instant: score:clt1@7.0 <-> perf:Chopin_Ashkenazy:cpt1@16.6),
#  MatchClaim(instant: score:clt1@7.5 <-> perf:Chopin_Ashkenazy:cpt1@17.0),
#  MatchClaim(instant: score:clt1@8.0 <-> perf:Chopin_Ashkenazy:cpt1@17.7),
#  MatchClaim(instant: score:clt1@8.5 <-> perf:Chopin_Ashkenazy:cpt1@18.1),
#  MatchClaim(instant: score:clt1@9.0 <-> perf:Chopin_Ashkenazy:cpt1@18.6),
#  MatchClaim(instant: score:clt1@9.5 <-> perf:Chopin_Ashkenazy:cpt1@19.1),
#  MatchClaim(instant: score:clt1@10.0 <-> perf:Chopin_Ashkenazy:cpt1@19.5),
#  MatchClaim(instant: score:clt1@10.5 <-> perf:Chopin_Ashkenazy:cpt1@19.9),
#  MatchClaim(instant: score:clt1@11.0 <-> perf:Chopin_Ashkenazy:cpt1@20.3),
#  MatchClaim(instant: score:clt1@11.5 <-> perf:Chopin_Ashkenazy:cpt1@20.6),
#  MatchClaim(instant: score:clt1@12.0 <-> perf:Chopin_Ashkenazy:cpt1@21.0),
#  MatchClaim(instant: score:clt1@12.5 <-> perf:Chopin_Ashkenazy:cpt1@21.5),
#  MatchClaim(instant: score:clt1@13.0 <-> perf:Chopin_Ashkenazy:cpt1@21.8),
#  MatchClaim(instant: score:clt1@13.5 <-> perf:Chopin_Ashkenazy:cpt1@22.2),
#  MatchClaim(instant: score:clt1@14.0 <-> perf:Chopin_Ashkenazy:cpt1@22.7),
#  MatchClaim(instant: score:clt1@14.5 <-> perf:Chopin_Ashkenazy:cpt1@23.0),
#  MatchClaim(instant: score:clt1@15.0 <-> perf:Chopin_Ashkenazy:cpt1@23.4),
#  MatchClaim(instant: score:clt1@15.5 <-> perf:Chopin_Ashkenazy:cpt1@23.8),
#  MatchClaim(instant: score:clt1@16.0 <-> perf:Chopin_Ashkenazy:cpt1@24.2),
#  MatchClaim(instant: score:clt1@16.5 <-> perf:Chopin_Ashkenazy:cpt1@24.6),
#  MatchClaim(instant: score:clt1@17.0 <-> perf:Chopin_Ashkenazy:cpt1@25.0),
#  MatchClaim(instant: score:clt1@17.5 <-> perf:Chopin_Ashkenazy:cpt1@25.4),
#  MatchClaim(instant: score:clt1@18.0 <-> perf:Chopin_Ashkenazy:cpt1@25.7),
#  MatchClaim(instant: score:clt1@18.5 <-> perf:Chopin_Ashkenazy:cpt1@26.3),
#  MatchClaim(instant: score:clt1@19.0 <-> perf:Chopin_Ashkenazy:cpt1@26.9),
#  MatchClaim(instant: score:clt1@19.5 <-> perf:Chopin_Ashkenazy:cpt1@27.4),
#  MatchClaim(instant: score:clt1@20.0 <-> perf:Chopin_Ashkenazy:cpt1@27.9),
#  MatchClaim(instant: score:clt1@20.5 <-> perf:Chopin_Ashkenazy:cpt1@28.4),
#  MatchClaim(instant: score:clt1@21.0 <-> perf:Chopin_Ashkenazy:cpt1@28.9),
#  MatchClaim(instant: score:clt1@21.5 <-> perf:Chopin_Ashkenazy:cpt1@29.6),
#  MatchClaim(instant: score:clt1@22.0 <-> perf:Chopin_Ashkenazy:cpt1@30.0),
# ...
#  MatchClaim(instant: score:clt1@100.0 <-> perf:Chopin_Ashkenazy:cpt1@109.6),
#  MatchClaim(instant: score:clt1@100.5 <-> perf:Chopin_Ashkenazy:cpt1@110.0),
#  MatchClaim(instant: score:clt1@101.0 <-> perf:Chopin_Ashkenazy:cpt1@110.4),
#  MatchClaim(instant: score:clt1@101.5 <-> perf:Chopin_Ashkenazy:cpt1@110.8),
#  MatchClaim(instant: score:clt1@102.0 <-> perf:Chopin_Ashkenazy:cpt1@111.2),
#  MatchClaim(instant: score:clt1@102.5 <-> perf:Chopin_Ashkenazy:cpt1@111.9),
#  MatchClaim(instant: score:clt1@103.0 <-> perf:Chopin_Ashkenazy:cpt1@112.4),
#  MatchClaim(instant: score:clt1@103.5 <-> perf:Chopin_Ashkenazy:cpt1@112.9),
#  MatchClaim(instant: score:clt1@104.0 <-> perf:Chopin_Ashkenazy:cpt1@113.4),
#  MatchClaim(instant: score:clt1@104.5 <-> perf:Chopin_Ashkenazy:cpt1@113.9),
#  MatchClaim(instant: score:clt1@105.0 <-> perf:Chopin_Ashkenazy:cpt1@114.6),
#  MatchClaim(instant: score:clt1@105.5 <-> perf:Chopin_Ashkenazy:cpt1@115.7),
#  MatchClaim(instant: score:clt1@106.0 <-> perf:Chopin_Ashkenazy:cpt1@116.3),
#  MatchClaim(instant: score:clt1@106.5 <-> perf:Chopin_Ashkenazy:cpt1@116.7),
#  MatchClaim(instant: score:clt1@107.0 <-> perf:Chopin_Ashkenazy:cpt1@117.1),
#  MatchClaim(instant: score:clt1@107.5 <-> perf:Chopin_Ashkenazy:cpt1@117.5),
#  MatchClaim(instant: score:clt1@108.0 <-> perf:Chopin_Ashkenazy:cpt1@117.9),
#  MatchClaim(instant: score:clt1@108.5 <-> perf:Chopin_Ashkenazy:cpt1@118.4),
#  MatchClaim(instant: score:clt1@109.0 <-> perf:Chopin_Ashkenazy:cpt1@118.9),
#  MatchClaim(instant: score:clt1@109.5 <-> perf:Chopin_Ashkenazy:cpt1@119.3),
#  MatchClaim(instant: score:clt1@110.0 <-> perf:Chopin_Ashkenazy:cpt1@119.7),
#  MatchClaim(instant: score:clt1@110.5 <-> perf:Chopin_Ashkenazy:cpt1@120.1),
#  MatchClaim(instant: score:clt1@111.0 <-> perf:Chopin_Ashkenazy:cpt1@120.5),
#  MatchClaim(instant: score:clt1@111.5 <-> perf:Chopin_Ashkenazy:cpt1@120.9),
#  MatchClaim(instant: score:clt1@112.0 <-> perf:Chopin_Ashkenazy:cpt1@121.3),
#  MatchClaim(instant: score:clt1@112.5 <-> perf:Chopin_Ashkenazy:cpt1@121.7),
#  MatchClaim(instant: score:clt1@113.0 <-> perf:Chopin_Ashkenazy:cpt1@122.1),
#  MatchClaim(instant: score:clt1@113.5 <-> perf:Chopin_Ashkenazy:cpt1@122.5),
#  MatchClaim(instant: score:clt1@114.0 <-> perf:Chopin_Ashkenazy:cpt1@122.9),
#  MatchClaim(instant: score:clt1@114.5 <-> perf:Chopin_Ashkenazy:cpt1@123.4),
#  MatchClaim(instant: score:clt1@115.0 <-> perf:Chopin_Ashkenazy:cpt1@123.9),
#  MatchClaim(instant: score:clt1@115.5 <-> perf:Chopin_Ashkenazy:cpt1@124.3),
#  MatchClaim(instant: score:clt1@116.0 <-> perf:Chopin_Ashkenazy:cpt1@124.8),
#  MatchClaim(instant: score:clt1@116.5 <-> perf:Chopin_Ashkenazy:cpt1@125.3),
#  MatchClaim(instant: score:clt1@117.0 <-> perf:Chopin_Ashkenazy:cpt1@125.7),
#  MatchClaim(instant: score:clt1@117.5 <-> perf:Chopin_Ashkenazy:cpt1@126.3),
#  MatchClaim(instant: score:clt1@118.0 <-> perf:Chopin_Ashkenazy:cpt1@127.2),
#  MatchClaim(instant: score:clt1@118.5 <-> perf:Chopin_Ashkenazy:cpt1@127.9),
#  MatchClaim(instant: score:clt1@119.0 <-> perf:Chopin_Ashkenazy:cpt1@128.4),
#  MatchClaim(instant: score:clt1@119.5 <-> perf:Chopin_Ashkenazy:cpt1@129.0),
#  MatchClaim(instant: score:clt1@120.0 <-> perf:Chopin_Ashkenazy:cpt1@129.7),
#  MatchClaim(instant: score:clt1@120.5 <-> perf:Chopin_Ashkenazy:cpt1@130.7),
#  MatchClaim(instant: score:clt1@121.0 <-> perf:Chopin_Ashkenazy:cpt1@131.6),
#  MatchClaim(instant: score:clt1@121.5 <-> perf:Chopin_Ashkenazy:cpt1@132.2),
#  MatchClaim(instant: score:clt1@122.0 <-> perf:Chopin_Ashkenazy:cpt1@132.8),
#  MatchClaim(instant: score:clt1@122.5 <-> perf:Chopin_Ashkenazy:cpt1@133.2),
#  MatchClaim(instant: score:clt1@123.0 <-> perf:Chopin_Ashkenazy:cpt1@133.9),
#  MatchClaim(instant: score:clt1@123.5 <-> perf:Chopin_Ashkenazy:cpt1@134.7),
#  MatchClaim(instant: score:clt1@124.0 <-> perf:Chopin_Ashkenazy:cpt1@135.2),
#  MatchClaim(instant: score:clt1@124.5 <-> perf:Chopin_Ashkenazy:cpt1@135.8),
#  MatchClaim(instant: score:clt1@125.0 <-> perf:Chopin_Ashkenazy:cpt1@136.3),
#  MatchClaim(instant: score:clt1@125.5 <-> perf:Chopin_Ashkenazy:cpt1@136.8),
#  MatchClaim(instant: score:clt1@126.0 <-> perf:Chopin_Ashkenazy:cpt1@137.3),
#  MatchClaim(instant: score:clt1@126.5 <-> perf:Chopin_Ashkenazy:cpt1@137.7),
#  MatchClaim(instant: score:clt1@127.0 <-> perf:Chopin_Ashkenazy:cpt1@138.2),
#  MatchClaim(instant: score:clt1@127.5 <-> perf:Chopin_Ashkenazy:cpt1@138.6),
#  MatchClaim(instant: score:clt1@128.0 <-> perf:Chopin_Ashkenazy:cpt1@139.0),
#  MatchClaim(instant: score:clt1@128.5 <-> perf:Chopin_Ashkenazy:cpt1@139.4),
#  MatchClaim(instant: score:clt1@129.0 <-> perf:Chopin_Ashkenazy:cpt1@140.2),
#  MatchClaim(instant: score:clt1@129.5 <-> perf:Chopin_Ashkenazy:cpt1@141.1),
#  MatchClaim(instant: score:clt1@130.0 <-> perf:Chopin_Ashkenazy:cpt1@141.8),
#  MatchClaim(instant: score:clt1@130.5 <-> perf:Chopin_Ashkenazy:cpt1@142.3),
#  MatchClaim(instant: score:clt1@131.0 <-> perf:Chopin_Ashkenazy:cpt1@142.8),
#  MatchClaim(instant: score:clt1@131.5 <-> perf:Chopin_Ashkenazy:cpt1@143.4),
#  MatchClaim(instant: score:clt1@132.0 <-> perf:Chopin_Ashkenazy:cpt1@143.8),
#  MatchClaim(instant: score:clt1@132.5 <-> perf:Chopin_Ashkenazy:cpt1@144.4),
#  MatchClaim(instant: score:clt1@133.0 <-> perf:Chopin_Ashkenazy:cpt1@144.8),
#  MatchClaim(instant: score:clt1@133.5 <-> perf:Chopin_Ashkenazy:cpt1@145.3),
#  MatchClaim(instant: score:clt1@134.0 <-> perf:Chopin_Ashkenazy:cpt1@145.9),
#  MatchClaim(instant: score:clt1@134.5 <-> perf:Chopin_Ashkenazy:cpt1@146.5),
#  MatchClaim(instant: score:clt1@135.0 <-> perf:Chopin_Ashkenazy:cpt1@147.0),
#  MatchClaim(instant: score:clt1@135.5 <-> perf:Chopin_Ashkenazy:cpt1@147.5),
#  MatchClaim(instant: score:clt1@136.0 <-> perf:Chopin_Ashkenazy:cpt1@148.0),
#  MatchClaim(instant: score:clt1@136.5 <-> perf:Chopin_Ashkenazy:cpt1@148.4),
#  MatchClaim(instant: score:clt1@137.0 <-> perf:Chopin_Ashkenazy:cpt1@148.9),
#  MatchClaim(instant: score:clt1@137.5 <-> perf:Chopin_Ashkenazy:cpt1@149.4),
#  MatchClaim(instant: score:clt1@138.0 <-> perf:Chopin_Ashkenazy:cpt1@149.8),
#  MatchClaim(instant: score:clt1@138.5 <-> perf:Chopin_Ashkenazy:cpt1@150.5),
#  MatchClaim(instant: score:clt1@139.0 <-> perf:Chopin_Ashkenazy:cpt1@151.5),
#  MatchClaim(instant: score:clt1@139.5 <-> perf:Chopin_Ashkenazy:cpt1@152.5),
#  MatchClaim(instant: score:clt1@140.0 <-> perf:Chopin_Ashkenazy:cpt1@153.2),
#  MatchClaim(instant: score:clt1@140.5 <-> perf:Chopin_Ashkenazy:cpt1@153.7),
#  MatchClaim(instant: score:clt1@141.0 <-> perf:Chopin_Ashkenazy:cpt1@154.5),
#  MatchClaim(instant: score:clt1@141.5 <-> perf:Chopin_Ashkenazy:cpt1@156.2),
#  MatchClaim(instant: score:clt1@142.0 <-> perf:Chopin_Ashkenazy:cpt1@156.8),
#  MatchClaim(instant: score:clt1@142.5 <-> perf:Chopin_Ashkenazy:cpt1@157.3),
#  MatchClaim(instant: score:clt1@143.0 <-> perf:Chopin_Ashkenazy:cpt1@157.7),
#  MatchClaim(instant: score:clt1@143.5 <-> perf:Chopin_Ashkenazy:cpt1@158.2),
#  MatchClaim(instant: score:clt1@144.0 <-> perf:Chopin_Ashkenazy:cpt1@158.8),
#  MatchClaim(instant: score:clt1@144.5 <-> perf:Chopin_Ashkenazy:cpt1@159.6),
#  MatchClaim(instant: score:clt1@145.0 <-> perf:Chopin_Ashkenazy:cpt1@160.3),
#  MatchClaim(instant: score:clt1@145.5 <-> perf:Chopin_Ashkenazy:cpt1@161.1),
#  MatchClaim(instant: score:clt1@146.0 <-> perf:Chopin_Ashkenazy:cpt1@161.8),
#  MatchClaim(instant: score:clt1@146.5 <-> perf:Chopin_Ashkenazy:cpt1@162.3),
#  MatchClaim(instant: score:clt1@147.0 <-> perf:Chopin_Ashkenazy:cpt1@162.9),
#  MatchClaim(instant: score:clt1@147.5 <-> perf:Chopin_Ashkenazy:cpt1@163.6),
#  MatchClaim(instant: score:clt1@148.0 <-> perf:Chopin_Ashkenazy:cpt1@164.4),
#  MatchClaim(instant: score:clt1@148.5 <-> perf:Chopin_Ashkenazy:cpt1@164.9),
#  MatchClaim(instant: score:clt1@149.0 <-> perf:Chopin_Ashkenazy:cpt1@165.3),
#  MatchClaim(instant: score:clt1@149.5 <-> perf:Chopin_Ashkenazy:cpt1@165.8),
#  MatchClaim(instant: score:clt1@150.0 <-> perf:Chopin_Ashkenazy:cpt1@166.3),
#  MatchClaim(instant: score:clt1@150.5 <-> perf:Chopin_Ashkenazy:cpt1@167.2),
#  MatchClaim(instant: score:clt1@151.0 <-> perf:Chopin_Ashkenazy:cpt1@167.9),
#  MatchClaim(instant: score:clt1@151.5 <-> perf:Chopin_Ashkenazy:cpt1@168.4),
#  MatchClaim(instant: score:clt1@152.0 <-> perf:Chopin_Ashkenazy:cpt1@168.9),
#  MatchClaim(instant: score:clt1@152.5 <-> perf:Chopin_Ashkenazy:cpt1@169.5),
#  MatchClaim(instant: score:clt1@153.0 <-> perf:Chopin_Ashkenazy:cpt1@170.0),
#  MatchClaim(instant: score:clt1@153.5 <-> perf:Chopin_Ashkenazy:cpt1@170.6),
#  MatchClaim(instant: score:clt1@154.0 <-> perf:Chopin_Ashkenazy:cpt1@171.2),
#  MatchClaim(instant: score:clt1@154.5 <-> perf:Chopin_Ashkenazy:cpt1@171.8),
#  MatchClaim(instant: score:clt1@155.0 <-> perf:Chopin_Ashkenazy:cpt1@173.0),
#  MatchClaim(instant: score:clt1@155.5 <-> perf:Chopin_Ashkenazy:cpt1@173.7),
#  MatchClaim(instant: score:clt1@156.0 <-> perf:Chopin_Ashkenazy:cpt1@174.2),
#  MatchClaim(instant: score:clt1@156.5 <-> perf:Chopin_Ashkenazy:cpt1@174.8),
#  MatchClaim(instant: score:clt1@157.0 <-> perf:Chopin_Ashkenazy:cpt1@175.4),
#  MatchClaim(instant: score:clt1@157.5 <-> perf:Chopin_Ashkenazy:cpt1@175.8),
#  MatchClaim(instant: score:clt1@158.0 <-> perf:Chopin_Ashkenazy:cpt1@176.3),
#  MatchClaim(instant: score:clt1@158.5 <-> perf:Chopin_Ashkenazy:cpt1@176.7),
#  MatchClaim(instant: score:clt1@159.0 <-> perf:Chopin_Ashkenazy:cpt1@177.1),
#  MatchClaim(instant: score:clt1@159.5 <-> perf:Chopin_Ashkenazy:cpt1@177.6),
#  MatchClaim(instant: score:clt1@160.0 <-> perf:Chopin_Ashkenazy:cpt1@178.1),
#  MatchClaim(instant: score:clt1@160.5 <-> perf:Chopin_Ashkenazy:cpt1@178.6),
#  MatchClaim(instant: score:clt1@161.0 <-> perf:Chopin_Ashkenazy:cpt1@179.6),
#  MatchClaim(instant: score:clt1@161.5 <-> perf:Chopin_Ashkenazy:cpt1@180.4),
#  MatchClaim(instant: score:clt1@162.0 <-> perf:Chopin_Ashkenazy:cpt1@181.0),
#  MatchClaim(instant: score:clt1@162.5 <-> perf:Chopin_Ashkenazy:cpt1@181.6),
#  MatchClaim(instant: score:clt1@163.0 <-> perf:Chopin_Ashkenazy:cpt1@182.1),
#  MatchClaim(instant: score:clt1@163.5 <-> perf:Chopin_Ashkenazy:cpt1@182.7),
#  MatchClaim(instant: score:clt1@164.0 <-> perf:Chopin_Ashkenazy:cpt1@183.3),
#  MatchClaim(instant: score:clt1@164.5 <-> perf:Chopin_Ashkenazy:cpt1@183.9),
#  MatchClaim(instant: score:clt1@165.0 <-> perf:Chopin_Ashkenazy:cpt1@184.8),
#  MatchClaim(instant: score:clt1@165.5 <-> perf:Chopin_Ashkenazy:cpt1@185.9),
#  MatchClaim(instant: score:clt1@166.0 <-> perf:Chopin_Ashkenazy:cpt1@186.6),
#  MatchClaim(instant: score:clt1@166.5 <-> perf:Chopin_Ashkenazy:cpt1@187.1),
#  MatchClaim(instant: score:clt1@167.0 <-> perf:Chopin_Ashkenazy:cpt1@187.6),
#  MatchClaim(instant: score:clt1@167.5 <-> perf:Chopin_Ashkenazy:cpt1@188.1),
#  MatchClaim(instant: score:clt1@168.0 <-> perf:Chopin_Ashkenazy:cpt1@188.6),
#  MatchClaim(instant: score:clt1@168.5 <-> perf:Chopin_Ashkenazy:cpt1@189.5),
#  MatchClaim(instant: score:clt1@169.0 <-> perf:Chopin_Ashkenazy:cpt1@190.4),
#  MatchClaim(instant: score:clt1@169.5 <-> perf:Chopin_Ashkenazy:cpt1@190.8),
#  MatchClaim(instant: score:clt1@170.0 <-> perf:Chopin_Ashkenazy:cpt1@191.4),
#  MatchClaim(instant: score:clt1@170.5 <-> perf:Chopin_Ashkenazy:cpt1@191.9),
#  MatchClaim(instant: score:clt1@171.0 <-> perf:Chopin_Ashkenazy:cpt1@192.6),
#  MatchClaim(instant: score:clt1@171.5 <-> perf:Chopin_Ashkenazy:cpt1@193.4),
#  MatchClaim(instant: score:clt1@172.0 <-> perf:Chopin_Ashkenazy:cpt1@193.9),
#  MatchClaim(instant: score:clt1@172.5 <-> perf:Chopin_Ashkenazy:cpt1@194.4),
#  MatchClaim(instant: score:clt1@173.0 <-> perf:Chopin_Ashkenazy:cpt1@194.8),
#  MatchClaim(instant: score:clt1@173.5 <-> perf:Chopin_Ashkenazy:cpt1@195.2),
#  MatchClaim(instant: score:clt1@174.0 <-> perf:Chopin_Ashkenazy:cpt1@195.6),
#  MatchClaim(instant: score:clt1@174.5 <-> perf:Chopin_Ashkenazy:cpt1@196.2),
#  MatchClaim(instant: score:clt1@175.0 <-> perf:Chopin_Ashkenazy:cpt1@196.8),
#  MatchClaim(instant: score:clt1@175.5 <-> perf:Chopin_Ashkenazy:cpt1@197.2),
#  MatchClaim(instant: score:clt1@176.0 <-> perf:Chopin_Ashkenazy:cpt1@197.6),
#  MatchClaim(instant: score:clt1@176.5 <-> perf:Chopin_Ashkenazy:cpt1@198.0),
#  MatchClaim(instant: score:clt1@177.0 <-> perf:Chopin_Ashkenazy:cpt1@198.4),
#  MatchClaim(instant: score:clt1@177.5 <-> perf:Chopin_Ashkenazy:cpt1@199.0),
#  MatchClaim(instant: score:clt1@178.0 <-> perf:Chopin_Ashkenazy:cpt1@199.6),
#  MatchClaim(instant: score:clt1@178.5 <-> perf:Chopin_Ashkenazy:cpt1@200.2),
#  MatchClaim(instant: score:clt1@179.0 <-> perf:Chopin_Ashkenazy:cpt1@200.6),
#  MatchClaim(instant: score:clt1@179.5 <-> perf:Chopin_Ashkenazy:cpt1@201.0),
#  MatchClaim(instant: score:clt1@180.0 <-> perf:Chopin_Ashkenazy:cpt1@201.4),
#  MatchClaim(instant: score:clt1@180.5 <-> perf:Chopin_Ashkenazy:cpt1@201.8),
#  MatchClaim(instant: score:clt1@181.0 <-> perf:Chopin_Ashkenazy:cpt1@202.1),
#  MatchClaim(instant: score:clt1@181.5 <-> perf:Chopin_Ashkenazy:cpt1@202.4),
#  MatchClaim(instant: score:clt1@182.0 <-> perf:Chopin_Ashkenazy:cpt1@202.8),
#  MatchClaim(instant: score:clt1@182.5 <-> perf:Chopin_Ashkenazy:cpt1@203.2),
#  MatchClaim(instant: score:clt1@183.0 <-> perf:Chopin_Ashkenazy:cpt1@203.5),
#  MatchClaim(instant: score:clt1@183.5 <-> perf:Chopin_Ashkenazy:cpt1@203.9),
#  MatchClaim(instant: score:clt1@184.0 <-> perf:Chopin_Ashkenazy:cpt1@204.4),
#  MatchClaim(instant: score:clt1@184.5 <-> perf:Chopin_Ashkenazy:cpt1@204.9),
#  MatchClaim(instant: score:clt1@185.0 <-> perf:Chopin_Ashkenazy:cpt1@205.2),
#  MatchClaim(instant: score:clt1@185.5 <-> perf:Chopin_Ashkenazy:cpt1@205.7),
#  MatchClaim(instant: score:clt1@186.0 <-> perf:Chopin_Ashkenazy:cpt1@206.3),
#  MatchClaim(instant: score:clt1@186.5 <-> perf:Chopin_Ashkenazy:cpt1@207.0),
#  MatchClaim(instant: score:clt1@188.0 <-> perf:Chopin_Ashkenazy:cpt1@208.1),
#  MatchClaim(instant: score:clt1@189.5 <-> perf:Chopin_Ashkenazy:cpt1@209.1),
#  MatchClaim(instant: score:clt1@0.0 <-> perf:Chopin_Barenboim:cpt1@0.3),
#  MatchClaim(instant: score:clt1@0.5 <-> perf:Chopin_Barenboim:cpt1@1.2),
#  MatchClaim(instant: score:clt1@1.0 <-> perf:Chopin_Barenboim:cpt1@1.9),
#  MatchClaim(instant: score:clt1@1.5 <-> perf:Chopin_Barenboim:cpt1@2.4),
#  MatchClaim(instant: score:clt1@2.0 <-> perf:Chopin_Barenboim:cpt1@2.9),
#  MatchClaim(instant: score:clt1@2.5 <-> perf:Chopin_Barenboim:cpt1@3.4),
#  MatchClaim(instant: score:clt1@3.0 <-> perf:Chopin_Barenboim:cpt1@4.0),
#  MatchClaim(instant: score:clt1@3.5 <-> perf:Chopin_Barenboim:cpt1@4.6),
#  MatchClaim(instant: score:clt1@4.0 <-> perf:Chopin_Barenboim:cpt1@5.2),
#  MatchClaim(instant: score:clt1@4.5 <-> perf:Chopin_Barenboim:cpt1@5.6),
#  MatchClaim(instant: score:clt1@5.0 <-> perf:Chopin_Barenboim:cpt1@6.2),
#  MatchClaim(instant: score:clt1@5.5 <-> perf:Chopin_Barenboim:cpt1@6.7),
#  MatchClaim(instant: score:clt1@6.0 <-> perf:Chopin_Barenboim:cpt1@7.2),
#  MatchClaim(instant: score:clt1@6.5 <-> perf:Chopin_Barenboim:cpt1@7.8),
#  MatchClaim(instant: score:clt1@7.0 <-> perf:Chopin_Barenboim:cpt1@8.3),
#  MatchClaim(instant: score:clt1@7.5 <-> perf:Chopin_Barenboim:cpt1@8.8),
#  MatchClaim(instant: score:clt1@8.0 <-> perf:Chopin_Barenboim:cpt1@9.5),
#  MatchClaim(instant: score:clt1@8.5 <-> perf:Chopin_Barenboim:cpt1@10.0),
#  MatchClaim(instant: score:clt1@9.0 <-> perf:Chopin_Barenboim:cpt1@10.5),
#  MatchClaim(instant: score:clt1@9.5 <-> perf:Chopin_Barenboim:cpt1@11.2),
#  MatchClaim(instant: score:clt1@10.0 <-> perf:Chopin_Barenboim:cpt1@11.7),
#  MatchClaim(instant: score:clt1@10.5 <-> perf:Chopin_Barenboim:cpt1@12.2),
#  MatchClaim(instant: score:clt1@11.0 <-> perf:Chopin_Barenboim:cpt1@12.8),
#  MatchClaim(instant: score:clt1@11.5 <-> perf:Chopin_Barenboim:cpt1@13.3),
#  MatchClaim(instant: score:clt1@12.0 <-> perf:Chopin_Barenboim:cpt1@13.8),
#  MatchClaim(instant: score:clt1@12.5 <-> perf:Chopin_Barenboim:cpt1@14.3),
#  MatchClaim(instant: score:clt1@13.0 <-> perf:Chopin_Barenboim:cpt1@14.8),
#  MatchClaim(instant: score:clt1@13.5 <-> perf:Chopin_Barenboim:cpt1@15.3),
#  MatchClaim(instant: score:clt1@14.0 <-> perf:Chopin_Barenboim:cpt1@15.9),
#  MatchClaim(instant: score:clt1@14.5 <-> perf:Chopin_Barenboim:cpt1@16.5),
#  MatchClaim(instant: score:clt1@15.0 <-> perf:Chopin_Barenboim:cpt1@17.0),
#  MatchClaim(instant: score:clt1@15.5 <-> perf:Chopin_Barenboim:cpt1@17.6),
#  MatchClaim(instant: score:clt1@16.0 <-> perf:Chopin_Barenboim:cpt1@18.1),
#  ...]

# %%
ashkenazy_claims = [c for c in bundle.cross_group_claims if c.connects(ashkenazy.id)]
by_granularity = Counter(c.metadata.agent.identifier for c in ashkenazy_claims)
dict(by_granularity)
# Out:
# {'note': 559, 'bar': 32, 'beats': 376}

# %% [markdown]
# At the note level, not every score note is found in the recording: where the
# aligner located no onset, the row is recorded as a {{< glossary NOMATCH >}}
# rather than discarded, so the dangling score position is preserved. Splitting
# the note-level claims into located and {{< glossary NOMATCH >}} makes the
# distinction explicit:

# %%
note_claims = [c for c in ashkenazy_claims if c.metadata.agent.identifier == "note"]

{
    "note claims (total)": len(note_claims),
    "located (synchronous)": sum(1 for c in note_claims if c.is_synchronous),
    "NOMATCH (no onset found)": sum(1 for c in note_claims if not c.is_synchronous),
}
# Out:
# {'note claims (total)': 559,
#  'located (synchronous)': 480,
#  'NOMATCH (no onset found)': 79}

# %% [markdown]
# A single bar-level claim links a score quarter to a performed second. This one
# anchors the downbeat of the first full measure (quarter 0.5) to the moment
# Ashkenazy played it:

# %%
ashkenazy_bar_claims = [
    c for c in ashkenazy_claims if c.metadata.agent.identifier == "bar"
]
ashkenazy_bar_claims[0]
# Out:
# MatchClaim(instant: score:clt1@0.5 <-> perf:Chopin_Ashkenazy:cpt1@10.3)

# %% [markdown]
# ***
#
# ## 6. Comparing the performances
#
# The corpus exists to compare how performers shape the same music in time. The
# {{< glossary AlignmentBundle >}} answers this directly: given one score
# coordinate, `get_matchstamp_at` returns the corresponding coordinate on every
# connected timeline. A {{< glossary MatchStamp >}} at the first full downbeat is
# therefore one score quarter mapped to seven performed seconds:

# %%
downbeat = float(metrical_position_map.quarters_at(2))
stamp = bundle.get_matchstamp_at(downbeat, score_tl.id)
stamp
# Out:
# MatchStamp(perf:Chopin_Ashkenazy:cpt1=10.27, perf:Chopin_Freire:cpt1=1.54, perf:Chopin_Barenboim:cpt1=1.20, perf:Chopin_Rubinstein:cpt1=1.17, score:clt1=0.50, perf:Chopin_Pollini:cpt1=1.95, perf:Chopin_Horowitz:cpt1=0.96, perf:Chopin_Rachmaninoff:cpt1=5.73)

# %% [markdown]
# Reading that across a sequence of downbeats gives each performer's arrival time
# at each measure — the raw material of a tempo comparison. We take the first
# several measure downbeats, ask the bundle for each performer's onset there, and
# tabulate the seconds against the score quarters:

# %%
downbeat_mcs = range(2, 10)
rows = []
for mc in downbeat_mcs:
    quarters = float(metrical_position_map.quarters_at(mc))
    onset_stamp = bundle.get_matchstamp_at(quarters, score_tl.id)
    row = {"score (quarters)": quarters}
    for key in performer_keys:
        perf_id = loader.create_timeline(uid=key).id
        coord = onset_stamp.coordinates.get(perf_id)
        row[key.replace("Chopin_", "")] = (
            round(float(coord), 3) if coord is not None else None
        )
    rows.append(row)

tempo_table = pd.DataFrame(rows).set_index("score (quarters)")
tempo_table
# Out:
#                   Ashkenazy  Barenboim  Freire  Horowitz  Pollini  \
# score (quarters)
# 0.5                  10.272      1.200   1.536     0.960    1.952
# 6.5                  16.152      7.792   8.384     7.232    8.352
# 12.5                 21.456     14.304  15.040    14.208   14.848
# 18.5                 26.320     21.248  21.408    20.704   20.384
# 24.5                 32.672     29.248  28.542    28.352   27.232
# 30.5                 38.784     35.920  34.614    35.024   33.664
# 36.5                 44.320     42.688  40.998    42.112   40.432
# 42.5                 49.600     49.504  47.920    48.976   46.464
#
#                   Rachmaninoff  Rubinstein
# score (quarters)
# 0.5                      5.728       1.168
# 6.5                     13.072       7.696
# 12.5                    20.208      14.752
# 18.5                    27.520      21.888
# 24.5                    35.824      30.032
# 30.5                    42.848      36.896
# 36.5                    51.696      43.952
# 42.5                    60.208      51.344

# %% [markdown]
# Each column is one pianist's arrival times in seconds; each row is a shared
# score position. The gaps between successive rows within a column are the
# inter-downbeat durations — read down a column and the performer's local tempo
# is visible, read across a row and the performers' differing placements of the
# same beat stand side by side. The same procedure at the beat or note
# granularity yields a finer-grained timing profile, all from the one
# {{< glossary AlignmentBundle >}}.
