# %%
from pathlib import Path
from timetoalign import ContinuousLogicalTimeline, DiscreteLogicalTimeline, AudioLoader

DATA_DIR = Path("../../tests/data").resolve()
assert DATA_DIR.is_dir(), f"Data dir not found: {DATA_DIR}"
mp3_path = DATA_DIR / "supra" / "midi" / "fd660zf8362.mp3"
mp3 = AudioLoader().load(mp3_path)
mp3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 7
#       5 assert DATA_DIR.is_dir(), f"Data dir not found: {DATA_DIR}"
#       6 mp3_path = DATA_DIR / "supra" / "midi" / "fd660zf8362.mp3"
# ----> 7 mp3 = AudioLoader().load(mp3_path)
#       8 mp3
#
# File ~/git/tta/timetoalign/timetoalign/loader/physical/audio.py:233, in AudioLoader.load(self, path)
#     230     except Exception as e:
#     231         self._logger.debug(f"wave module failed for {path}: {e}")
# --> 233 raise ValueError(
#     234     f"Cannot read audio file '{path}'. "
#     235     "Install soundfile (pip install soundfile) for broad format support, "
#     236     "or mutagen (pip install mutagen) for MP3/M4A support."
#     237 )
#
# ValueError: Cannot read audio file '/home/laser/git/tta/timetoalign/tests/data/supra/midi/fd660zf8362.mp3'. Install soundfile (pip install soundfile) for broad format support, or mutagen (pip install mutagen) for MP3/M4A support.

# %%
tl = mp3.to_timeline()
tl

# %%
tl.add_conversion_map()

# %%
tsv_df

# %%
pt_df

# %%
m21_df

# %%
T = ContinuousLogicalTimeline()
U = DiscreteLogicalTimeline()
T

# %%
for store in tsv_bundle:
    T.add_child(ContinuousLogicalTimeline.from_event_store(store), 0)
T

# %%
T.events.table.to_pandas()
